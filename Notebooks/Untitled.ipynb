# %%
import requests
import json
import numpy as np
import pandas as pd
import time

with open('../Data/api_key.json') as fi:
    credentials = json.load(fi)
    
api_key = credentials['api_key']

header={
    "Accept":"application/json", 
    "x-api-key":api_key
}


beatles=requests.get("https://api.setlist.fm/rest/1.0/artist/b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d/setlists?p=1", headers=header)
print(beatles)
# Out:
# <Response [200]>

# %%
header={
    "Accept":"application/json", 
    "x-api-key":api_key
}

state={
    "stateCode":"TN"
}


states=['AL','AK','AZ','AR','CA','CO','CT','DE','DC','FL','GA','HI','ID','IL','IN','IA','KS','KY','LA','ME','MD','MA','MI','MN','MS','MO','MT','NE','NV','NH','NJ','NM','NY','NC','ND','OH','OK','OR','PA','PR','RI','SC','SD','TN','TX','UT','VT','VA','WA','WV','WI','WY']

venues_list = []

for x in states:
    print(requests.get(f"https://api.setlist.fm/rest/1.0/search/venues?p=1&stateCode={x}", headers=header))
    venues_list.append(requests.get(f"https://api.setlist.fm/rest/1.0/search/venues?p=1&stateCode={x}", headers=header).text)
    time.sleep(10)

# %%
# venues list of only 5 states so it takes less time to run

header={
    "Accept":"application/json", 
    "x-api-key":api_key
}

state={
    "stateCode":"TN"
}


states=['AL','AK','AZ','AR','CA']

venues_list = []

for x in states:
    print(requests.get(f"https://api.setlist.fm/rest/1.0/search/venues?p=1&stateCode={x}", headers=header))
    venues_list.append(requests.get(f"https://api.setlist.fm/rest/1.0/search/venues?p=1&stateCode={x}", headers=header).text)
    time.sleep(10)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %% [markdown]
# Trying different code on venues list. Below is what I've tried:

# %%
# venues_list.json() -  AttributeError: 'list' object has no attribute 'json'
# venues = json.loads(venues_list)
# venues = pd.DataFrame(venues_list)

# y = json.load(x)

# x = state_search_response.json()
# df_one = pd.DataFrame(x['venue'])
# df_one.head()

# res = {k: v for d in ini_dict for k, v in d.items()}


# var = json.loads(res.text)
# df_one = pd.DataFrame(var_two['venue'])
# df_one.head()

# %%
five_venues = json.loads(venues_list)
five_venues
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 five_venues = json.loads(venues_list)
#       2 five_venues
#
# File ~\anaconda3\lib\json\__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                         f'not {s.__class__.__name__}')
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
#
# TypeError: the JSON object must be str, bytes or bytearray, not list

# %%
five = {k: v for d in five_venues for k, v in d.items()}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [48], in <cell line: 3>()
#       1 # res = {k: v for d in ini_dict for k, v in d.items()}
# ----> 3 five = {k: v for d in five_venues for k, v in d.items()}
#
# Input In [48], in <dictcomp>(.0)
#       1 # res = {k: v for d in ini_dict for k, v in d.items()}
# ----> 3 five = {k: v for d in five_venues for k, v in d.items()}
#
# AttributeError: 'str' object has no attribute 'items'

# %%
# final = json.dumps(data, indent=2)

five_venues = json.dumps(venues_list, indent =1)
five_venues
# Out:
# '[\n "{\\n   \\"type\\" : \\"venues\\",\\n   \\"itemsPerPage\\" : 30,\\n   \\"page\\" : 1,\\n   \\"total\\" : 1176,\\n   \\"venue\\" : [ {\\n      \\"id\\" : \\"3d259ab\\",\\n      \\"name\\" : \\"the end.\\",\\n      \\"city\\" : {\\n         \\"id\\" : \\"4062577\\",\\n         \\"name\\" : \\"Florence\\",\\n         \\"state\\" : \\"Alabama\\",\\n         \\"stateCode\\" : \\"AL\\",\\n         \\"coords\\" : {\\n            \\"lat\\" : 34.79981,\\n            \\"long\\" : -87.677251\\n         },\\n         \\"country\\" : {\\n            \\"code\\" : \\"US\\",\\n            \\"name\\" : \\"United States\\"\\n         }\\n      },\\n      \\"url\\" : \\"https://www.setlist.fm/venue/the-end-florence-al-usa-3d259ab.html\\"\\n   }, {\\n      \\"id\\" : \\"1bd259b8\\",\\n      \\"name\\" : \\"en Fuego\\",\\n      \\"city\\" : {\\n         \\"id\\" : \\"4095369\\",\\n         \\"name\\" : \\"Verbena\\",\\n         \\"state\\" : \\"Alabama\\",\\n         \\"stateCode\\" : \\"AL\\",\\n  
# ...

# %%
# var_three = pd.DataFrame(dict([(k,pd.Series(v)) for k,v in df_one.items()]))

# %%
 five_venues = pd.DataFrame(venues_list)
five_venues[0][1]
# Out:
# '{\n   "type" : "venues",\n   "itemsPerPage" : 30,\n   "page" : 1,\n   "total" : 196,\n   "venue" : [ {\n      "id" : "73d27e25",\n      "name" : "Zudy\'s Cafe",\n      "city" : {\n         "id" : "5873776",\n         "name" : "Seward",\n         "state" : "Alaska",\n         "stateCode" : "AK",\n         "coords" : {\n            "lat" : 60.10417,\n            "long" : -149.44222\n         },\n         "country" : {\n            "code" : "US",\n            "name" : "United States"\n         }\n      },\n      "url" : "https://www.setlist.fm/venue/zudys-cafe-seward-ak-usa-73d27e25.html"\n   }, {\n      "id" : "73d25ed9",\n      "name" : "Yukon Bar",\n      "city" : {\n         "id" : "5873776",\n         "name" : "Seward",\n         "state" : "Alaska",\n         "stateCode" : "AK",\n         "coords" : {\n            "lat" : 60.10417,\n            "long" : -149.44222\n         },\n         "country" : {\n            "code" : "US",\n            "name" : "United States"\n         }\n  
# ...

# %%
venues_list

# %%
beatles_test = beatles.json()
ids = []
versionid = []
eventdate = []
lastupdated = []
artist = []
venue = []
song = []
cover = []
songinfo = []
for x in beatles_test['setlist']:
    for y in x['sets']['set'][0]['song']:
        song.append(y['name'])
        ids.append(x['id'])
        versionid.append(x['versionId'])
        eventdate.append(x['eventDate'])
        lastupdated.append(x['lastUpdated'])
        artist.append(x['artist']['name'])
        venue.append(x['venue']['name'])
        try: 
            cover.append(y['cover']['name'])
        except: 
            cover.append("original")
beatles_setlist = pd.DataFrame({'id': ids, 'versionid': versionid, 'eventdate': eventdate, 'lastupdated': lastupdated, 'artist': artist, 'venue': venue, 'song': song, 'cover': cover})
beatles_setlist.head(50)

# %%
# venues list of only 5 states so it takes less time to run

header={
    "Accept":"application/json", 
    "x-api-key":api_key
}

state={
    "stateCode":"TN"
}


states=['AL','AK','AZ','AR','CA']

venues_list = []

for x in states:
    print(requests.get(f"https://api.setlist.fm/rest/1.0/search/venues?p=1&stateCode={x}", headers=header))
    venues_list.append(requests.get(f"https://api.setlist.fm/rest/1.0/search/venues?p=1&stateCode={x}", headers=header).json())
    time.sleep(10)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
venues_list
# Out:
# [{'type': 'venues',
#   'itemsPerPage': 30,
#   'page': 1,
#   'total': 1177,
#   'venue': [{'id': '3d259ab',
#     'name': 'the end.',
#     'city': {'id': '4062577',
#      'name': 'Florence',
#      'state': 'Alabama',
#      'stateCode': 'AL',
#      'coords': {'lat': 34.79981, 'long': -87.677251},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/the-end-florence-al-usa-3d259ab.html'},
#    {'id': '1bd259b8',
#     'name': 'en Fuego',
#     'city': {'id': '4095369',
#      'name': 'Verbena',
#      'state': 'Alabama',
#      'stateCode': 'AL',
#      'coords': {'lat': 32.7498505, 'long': -86.5113668},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/en-fuego-verbena-al-usa-1bd259b8.html'},
#    {'id': '23d64807',
#     'name': 'Zydeco',
#     'city': {'id': '4049979',
#      'name': 'Birmingham',
#      'state': 'Alabama',
#      'stateCode': 'AL',
# ...

# %%
five_venues = pd.DataFrame(venues_list)
five_venues
# venues_list.json() -  AttributeError: 'list' object has no attribute 'json'
# venues = json.loads(venues_list)
# venues = pd.DataFrame(venues_list)

# y = json.load(x)

# x = state_search_response.json()
# df_one = pd.DataFrame(x['venue'])
# df_one.head()

# res = {k: v for d in ini_dict for k, v in d.items()}


# var = json.loads(res.text)
# df_one = pd.DataFrame(var_two['venue'])
# df_one.head()
# Out:
#      type  itemsPerPage  page  total  \
# 0  venues            30     1   1177
# 1  venues            30     1    196
# 2  venues            30     1   1410
# 3  venues            30     1    617
# 4  venues            30     1  12428
#
#                                                venue
# 0  [{'id': '3d259ab', 'name': 'the end.', 'city':...
# 1  [{'id': '73d27e25', 'name': 'Zudy's Cafe', 'ci...
# 2  [{'id': '33d6d805', 'name': 'ZooBrew', 'city':...
# 3  [{'id': '1bd0c9d0', 'name': 'siDe BAr', 'city'...
# 4  [{'id': '3d389cb', 'name': 'wework', 'city': {...

# %%
# g_setlist_df = g_df['setlist'].apply(pd.Series)

five_venues_df = five_venues['venue'].apply(pd.Series)
five_venues_df.head()
# Out:
#                                                   0   \
# 0  {'id': '3d259ab', 'name': 'the end.', 'city': ...
# 1  {'id': '73d27e25', 'name': 'Zudy's Cafe', 'cit...
# 2  {'id': '33d6d805', 'name': 'ZooBrew', 'city': ...
# 3  {'id': '1bd0c9d0', 'name': 'siDe BAr', 'city':...
# 4  {'id': '3d389cb', 'name': 'wework', 'city': {'...
#
#                                                   1   \
# 0  {'id': '1bd259b8', 'name': 'en Fuego', 'city':...
# 1  {'id': '73d25ed9', 'name': 'Yukon Bar', 'city'...
# 2  {'id': '6bd5260a', 'name': 'Zia Records', 'cit...
# 3  {'id': '3bd5bcec', 'name': 'Zaza's', 'city': {...
# 4  {'id': '3bd7f4e8', 'name': 'ustream.tv', 'city...
#
#                                                   2   \
# 0  {'id': '23d64807', 'name': 'Zydeco', 'city': {...
# 1  {'id': '3d2f913', 'name': 'Wood Center Ballroo...
# 2  {'id': '1bd72d24', 'name': 'Zia Records', 'cit...
# 3  {'id': '63d5ae1b', 'name': 'ZAZA', 'city': {'i...
# ...

# %%
five_venues_df = five_venues['venue'].apply(pd.Series)
five_venues_df.head()

# %%
five_venues_df[0][0]['id']
# Out:
# '3d259ab'

# %%
five_venues_df[0][0]['name']
# Out:
# 'the end.'

# %%
five_venues_df[0][0]
# Out:
# {'id': '3d259ab',
#  'name': 'the end.',
#  'city': {'id': '4062577',
#   'name': 'Florence',
#   'state': 'Alabama',
#   'stateCode': 'AL',
#   'coords': {'lat': 34.79981, 'long': -87.677251},
#   'country': {'code': 'US', 'name': 'United States'}},
#  'url': 'https://www.setlist.fm/venue/the-end-florence-al-usa-3d259ab.html'}

# %%
five_venues['venue'][0][0]['name']
# Out:
# 'the end.'

# %%
ids = []
names = []
cities = []
states = []
city_ids = []
for x in five_venues['venue']: 
    ids.append(x[0]['id'])
    names.append(x[0]['name'])
    cities.append(x[0]['city']['name'])
    city_ids.append(x[0]['city']['id'])
    states.append(x[0]['city']['state'])
    
venues = pd.DataFrame({'id':ids, 'name':names, 'city':cities, 'state':states, 'id':city_ids})
venues.head()
# Out:
#         id         name            city       state
# 0  4062577     the end.        Florence     Alabama
# 1  5873776  Zudy's Cafe          Seward      Alaska
# 2  5308655      ZooBrew         Phoenix     Arizona
# 3  4110119     siDe BAr  Eureka Springs    Arkansas
# 4  5373121       wework     Mill Valley  California

# %%
five_venues_df 
ids = []
name = []
eventdate = []
lastupdated = []
artist = []
venue = []
song = []
cover = []
songinfo = []
for x in five_venues_df['venue']:
    for y in x[0][0]:
        song.append(y['id'])
        ids.append(x['id'])
        versionid.append(x['versionId'])
        eventdate.append(x['eventDate'])
        lastupdated.append(x['lastUpdated'])
        artist.append(x['artist']['name'])
        venue.append(x['venue']['name'])
        try: 
            cover.append(y['cover']['name'])
        except: 
            cover.append("original")
beatles_setlist = pd.DataFrame({'id': ids, 'versionid': versionid, 'eventdate': eventdate, 'lastupdated': lastupdated, 'artist': artist, 'venue': venue, 'song': song, 'cover': cover})
beatles_setlist.head(50)
