# %%
import requests
import json
import numpy as np
import pandas as pd
import time

with open('../Data/api_key.json') as fi:
    credentials = json.load(fi)
    
api_key = credentials['api_key']

# %%
header={
    "Accept":"application/json", 
    "x-api-key":api_key
}


a=requests.get("https://api.setlist.fm/rest/1.0/artist/af953ba2-283b-41ef-93bc-b4cfc5feeebc", headers=header)
print(a)
a_dict = a.json()
# Out:
# <Response [200]>

# %%
for key, value in a_dict.items():
    print(f"\nKey: {key}")
    print(f"Value: {value}\n")
# Out:
# Key: mbid
# Value: af953ba2-283b-41ef-93bc-b4cfc5feeebc
#
#
# Key: name
# Value: Darlene Love
#
#
# Key: sortName
# Value: Love, Darlene
#
#
# Key: disambiguation
# Value:
#
#
# Key: url
# Value: https://www.setlist.fm/setlists/darlene-love-bd69d4e.html

# %%
# data = [{'name': 'vikash', 'age': 27}, {'name': 'Satyam', 'age': 14}]
# df = pd.DataFrame.from_dict(data, orient='columns')

a_dict.keys()
# Out:
# dict_keys(['mbid', 'name', 'sortName', 'disambiguation', 'url'])

# %%
a_dict.values()
# Out:
# dict_values(['af953ba2-283b-41ef-93bc-b4cfc5feeebc', 'Darlene Love', 'Love, Darlene', '', 'https://www.setlist.fm/setlists/darlene-love-bd69d4e.html'])

# %%
a_dict.items()
# Out:
# dict_items([('mbid', 'af953ba2-283b-41ef-93bc-b4cfc5feeebc'), ('name', 'Darlene Love'), ('sortName', 'Love, Darlene'), ('disambiguation', ''), ('url', 'https://www.setlist.fm/setlists/darlene-love-bd69d4e.html')])

# %%
a_dict['name']
# Out:
# 'Darlene Love'

# %%
a_dict
# Out:
# {'mbid': 'af953ba2-283b-41ef-93bc-b4cfc5feeebc',
#  'name': 'Darlene Love',
#  'sortName': 'Love, Darlene',
#  'disambiguation': '',
#  'url': 'https://www.setlist.fm/setlists/darlene-love-bd69d4e.html'}

# %%
# loop to print all keys

for x in a_dict:
    print(x)
# Out:
# mbid
# name
# sortName
# disambiguation
# url

# %%
# loop to print all values

for x in a_dict:
    print(a_dict[x])
# Out:
# af953ba2-283b-41ef-93bc-b4cfc5feeebc
# Darlene Love
# Love, Darlene
#
# https://www.setlist.fm/setlists/darlene-love-bd69d4e.html

# %%
for x in a_dict.values():
    print(x)
# Out:
# af953ba2-283b-41ef-93bc-b4cfc5feeebc
# Darlene Love
# Love, Darlene
#
# https://www.setlist.fm/setlists/darlene-love-bd69d4e.html

# %%
for x in a_dict.keys():
    print(x)
# Out:
# mbid
# name
# sortName
# disambiguation
# url

# %%
for x, y in a_dict.items():
    print(x,y)
# Out:
# mbid af953ba2-283b-41ef-93bc-b4cfc5feeebc
# name Darlene Love
# sortName Love, Darlene
# disambiguation
# url https://www.setlist.fm/setlists/darlene-love-bd69d4e.html

# %%
# new = pd.DataFrame.from_dict(data)

# df = pd.DataFrame.from_dict(a_dict,index=[0])

a_df = pd.DataFrame(a_dict, index=[0])
a_df
# Out:
#                                    mbid          name       sortName  \
# 0  af953ba2-283b-41ef-93bc-b4cfc5feeebc  Darlene Love  Love, Darlene
#
#   disambiguation                                                url
# 0                 https://www.setlist.fm/setlists/darlene-love-b...

# %%
#  print("Type:", type(data))

print("Type:", type(a_dict)

# %%
# b_df=pd.DataFrame(b.json())
# b_df.head()

# b_setlist_df = b_df['setlist'].apply(pd.Series)
# b_setlist_df.head()

# %%
g_test = g.json()
ids = []
versionid = []
eventdate = []
lastupdated = []
artist = []
mbid = []
venue = []
song = []
for x in g_test['setlist']:
        song.append(y['name'])
        ids.append(x['id'])
        versionid.append(x['versionId'])
        eventdate.append(x['eventDate'])
        lastupdated.append(x['lastUpdated'])
        artist.append(x['artist']['name'])
        mbid.append(x['artist']['mbid'])
        venue.append(x['venue']['name'])
g_df_test = pd.DataFrame({'id': ids, 'versionid': versionid, 'eventdate': eventdate, 'lastupdated': lastupdated, 'artist': artist,'mbid':mbid, 'venue': venue, 'song': song})
g_df_test

# %%
header={
    "Accept":"application/json", 
    "x-api-key":api_key
}


d=requests.get("https://api.setlist.fm/rest/1.0/search/artists?artistName=The%20Beatles&p=1&sort=sortName", headers=header)
d_df=pd.DataFrame(d.json())
d_artist_df = d_df['artist'].apply(pd.Series)
d_artist_df.head()
# Out:
#                                    mbid                    name  \
# 0  9725f5a1-3d65-488a-8a82-54c1483beb7c        The Anal Beatles
# 1  ec996b5f-89c8-4dd6-8063-1bd8df438a00    The Backbeat Beatles
# 2  898e211b-06ad-460b-85ee-cd6ac337ef79  The Beatles Connection
# 3  31f6812d-12ab-406f-a13d-ad54976e49c6      The Cavern Beatles
# 4  f94d056f-68dc-4a99-b664-fa296a96240f  The Beatles First Five
#
#                   sortName        disambiguation  \
# 0        Anal Beatles, The
# 1    Backbeat Beatles, The
# 2  Beatles Connection, The  Beatles Tribute Band
# 3       Beatles Cover Band    Beatles Cover Band
# 4  Beatles First Five, The
#
#                                                  url
# 0  https://www.setlist.fm/setlists/the-anal-beatl...
# 1  https://www.setlist.fm/setlists/the-backbeat-b...
# 2  https://www.setlist.fm/setlists/the-beatles-co...
# 3  https://www.setlist.fm/setlists/the-cavern-bea...
# 4  https://www.setlist.fm/setlists/the-beatles-fi...

# %% [markdown]
# SEARCH SETLISTS using country code US

# %%
header={
    "Accept":"application/json", 
    "x-api-key":api_key
}


g=requests.get("https://api.setlist.fm/rest/1.0/search/setlists?countryCode=us&p=1", headers=header)
g_df=pd.DataFrame(g.json())

g_df
# Out:
#         type  itemsPerPage  page    total  \
# 0   setlists            20     1  2808972
# 1   setlists            20     1  2808972
# 2   setlists            20     1  2808972
# 3   setlists            20     1  2808972
# 4   setlists            20     1  2808972
# 5   setlists            20     1  2808972
# 6   setlists            20     1  2808972
# 7   setlists            20     1  2808972
# 8   setlists            20     1  2808972
# 9   setlists            20     1  2808972
# 10  setlists            20     1  2808972
# 11  setlists            20     1  2808972
# 12  setlists            20     1  2808972
# 13  setlists            20     1  2808972
# 14  setlists            20     1  2808972
# 15  setlists            20     1  2808972
# 16  setlists            20     1  2808972
# 17  setlists            20     1  2808972
# 18  setlists            20     1  2808972
# 19  setlists            20     1  2808972
#
#                                               setlist
# ...

# %%
g_setlist_df = g_df['setlist'].apply(pd.Series)
g_setlist_df.head()
# Out:
#          id  versionId   eventDate                   lastUpdated  \
# 0  53bf4f99  g43e2d3c7  10-12-2022  2022-12-08T00:17:59.000+0000
# 1  4bbf4f9a  g5be2d3c0  10-12-2022  2022-12-08T00:17:15.000+0000
# 2  43bf4f9b  g43e2d3c3  10-12-2022  2022-12-08T00:16:33.000+0000
# 3  5bbf4fa4  g53e2d3cd  10-12-2022  2022-12-08T00:15:43.000+0000
# 4  4bbf4fa6  g53e2d3c9  10-12-2022  2022-12-08T00:15:17.000+0000
#
#                                               artist  \
# 0  {'mbid': 'f6c6ff48-5198-47dc-a7c5-fd733dc379a2...
# 1  {'mbid': '0330a83d-f61e-4989-adb3-afce3943c3ba...
# 2  {'mbid': '3ac482b8-1494-4071-a0e9-f192f9d2c2b0...
# 3  {'mbid': '511562a6-c381-44df-9bc4-27be779716b8...
# 4  {'mbid': '511562a6-c381-44df-9bc4-27be779716b8...
#
#                                                venue  \
# 0  {'id': '43d63b03', 'name': 'The Moore Theatre'...
# 1  {'id': '1bd27580', 'name': 'Ritz Carlton', 'ci...
# 2  {'id': '1bd61950', 'name': 'Pappy & Harriet's ...
# ...

# %%
g_artist_df = g_setlist_df['artist'].apply(pd.Series)
g_artist_df
# Out:
#                                     mbid                     name  \
# 0   f6c6ff48-5198-47dc-a7c5-fd733dc379a2         Jake Shimabukuro
# 1   0330a83d-f61e-4989-adb3-afce3943c3ba               38 Special
# 2   3ac482b8-1494-4071-a0e9-f192f9d2c2b0           Built to Spill
# 3   511562a6-c381-44df-9bc4-27be779716b8        Tony! Toni! Toné!
# 4   511562a6-c381-44df-9bc4-27be779716b8        Tony! Toni! Toné!
# 5   d2b8465e-5020-4955-b21d-3ac24bbae7d3                  Keilana
# 6   a408ec83-2ee0-4cf2-99d6-161fbe76dd16                   Anuhea
# 7   aaa436da-b331-4e58-a0fd-3d64d090c120      A Flock of Seagulls
# 8   25b75a66-ce83-4db3-b136-395a3c3784c4    The New Pornographers
# 9   a616f35a-bbcc-42e4-9b50-0c95252eee2b            Super Diamond
# 10  84803b1d-dcb3-490d-9af5-debbba64a011             Soccer Mommy
# 11  af8e4cc5-ef54-458d-a194-7b210acf638f          Cannibal Corpse
# 12  c373c7f0-fddf-4c04-a327-19dd83590753               Immolation
# ...

# %%
g_artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   mbid            20 non-null     object
#  1   name            20 non-null     object
#  2   sortName        20 non-null     object
#  3   disambiguation  20 non-null     object
#  4   url             20 non-null     object
# dtypes: object(5)
# memory usage: 928.0+ bytes

# %%
ids = []
versionid = []
eventdate = []
lastupdated = []
artist = []
venue = []
song = []
for x in b_test['setlist']:
        song.append(y['name'])
        ids.append(x['id'])
        versionid.append(x['versionId'])
        eventdate.append(x['eventDate'])
        lastupdated.append(x['lastUpdated'])
        artist.append(x['artist']['name'])
        venue.append(x['venue']['name'])
b_setlist_test = pd.DataFrame({'id': ids, 'versionid': versionid, 'eventdate': eventdate, 'lastupdated': lastupdated, 'artist': artist, 'venue': venue, 'song': song})
b_setlist_test

# %%
header={
    "Accept":"application/json", 
    "x-api-key":api_key
}


i=requests.get("https://api.setlist.fm/rest/1.0/setlist/53d6f3ad", headers=header)
i_df=pd.DataFrame(i.json())
i_df.head()
# Out:
#                       id  versionId   eventDate                   lastUpdated  \
# mbid            53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# name            53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# sortName        53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# disambiguation  53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# url             53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
#
#                                                            artist  \
# mbid                         b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d
# name                                                  The Beatles
# sortName                                             Beatles, The
# disambiguation
# url             https://www.setlist.fm/setlists/the-beatles-23...
#
#                                                             venue sets  \
# mbid                                                          NaN  NaN
# ...

# %%
# rows: mbid, name, sortName, disambiguation, url, id, city, set
# columns: id, versionId, eventDate, lastUpdated, artist, venue, sets, info, url

# %%
# fifa_players.set_index('club')[['name', 'nationality']].transpose()

transposed_df =i_df.set_index('id')[['artist','venue']].transpose
transposed_df
# Out:
# <bound method DataFrame.transpose of                                                      artist  \
# id
# 53d6f3ad               b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d
# 53d6f3ad                                        The Beatles
# 53d6f3ad                                       Beatles, The
# 53d6f3ad
# 53d6f3ad  https://www.setlist.fm/setlists/the-beatles-23...
# 53d6f3ad                                                NaN
# 53d6f3ad                                                NaN
# 53d6f3ad                                                NaN
#
#                                                       venue
# id
# 53d6f3ad                                                NaN
# 53d6f3ad                                Apple Corps Rooftop
# 53d6f3ad                                                NaN
# 53d6f3ad                                                NaN
# 53d6f3ad  https://www.setlist.fm/venue/apple-corps-rooft...
# 53d6f3ad                                           4bd627fe
# ...

# %%
t = i_df.set_index('id')[['artist']].transpose
t
# Out:
# <bound method DataFrame.transpose of                                                      artist
# id
# 53d6f3ad               b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d
# 53d6f3ad                                        The Beatles
# 53d6f3ad                                       Beatles, The
# 53d6f3ad
# 53d6f3ad  https://www.setlist.fm/setlists/the-beatles-23...
# 53d6f3ad                                                NaN
# 53d6f3ad                                                NaN
# 53d6f3ad                                                NaN>

# %%
# another_fifa.pivot(index="name", columns="variable")

# i_df = i_df.pivot(index='artist', columns='venue')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\arrays\categorical.py:438, in Categorical.__init__(self, values, categories, ordered, dtype, fastpath, copy)
#     437 try:
# --> 438     codes, categories = factorize(values, sort=True)
#     439 except TypeError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\core\algorithms.py:763, in factorize(values, sort, na_sentinel, size_hint)
#     761         na_value = None
# --> 763     codes, uniques = factorize_array(
#     764         values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     765     )
#     767 if sort and len(uniques) > 0:
#
# File ~\anaconda3\lib\site-packages\pandas\core\algorithms.py:560, in factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     559 table = hash_klass(size_hint or len(values))
# ...

# %%
m
