# %%
import requests
import json
import numpy as np
import pandas as pd
import time

with open('../Data/api_key.json') as fi:
    credentials = json.load(fi)
    
api_key = credentials['api_key']

# %%
header={
    "Accept":"application/json", 
    "x-api-key":api_key
}


b=requests.get("https://api.setlist.fm/rest/1.0/artist/b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d/setlists?p=1", headers=header)
print(b)
# Out:
# <Response [200]>

# %%
b

# %%
# response.json()

b.json()
# Out:
# {'type': 'setlists',
#  'itemsPerPage': 20,
#  'page': 1,
#  'total': 1466,
#  'setlist': [{'id': '53d6f3ad',
#    'versionId': 'g53c29b9d',
#    'eventDate': '30-01-1969',
#    'lastUpdated': '2021-12-14T08:26:08.000+0000',
#    'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#     'name': 'The Beatles',
#     'sortName': 'Beatles, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#    'venue': {'id': '4bd627fe',
#     'name': 'Apple Corps Rooftop',
#     'city': {'id': '2643743',
#      'name': 'London',
#      'state': 'England',
#      'stateCode': 'ENG',
#      'coords': {'lat': 51.5084152563931, 'long': -0.125532746315002},
#      'country': {'code': 'GB', 'name': 'United Kingdom'}},
#     'url': 'https://www.setlist.fm/venue/apple-corps-rooftop-london-england-4bd627fe.html'},
#    'sets': {'set': [{'song': [{'name': 'Get Back'},
#        {'name': 'Get Back'},
#        {'name': "Don't Let Me Down"},
#        {'name': "I've Got a Feeling"},
#        {'name': 'One After 909', 'info': 'with "Danny Boy" tease'},
#        {'name': 'Dig a Pony', 'info': 'with a false start'},
#        {'name': 'God Save the Queen',
#         'cover': {'mbid': '9be7f096-97ec-4615-8957-8d40b5dcbc41',
#          'name': '[traditional]',
#          'sortName': '[traditional]',
#          'disambiguation': 'Special Purpose Artist',
#          'url': 'https://www.setlist.fm/setlists/traditional-5bd2f7e4.html'},
#         'info': 'Jam'},
#        {'name': "I've Got a Feeling",
#         'info': 'with "A Pretty Girl Is Like a Melody" tease'},
#        {'name': "Don't Let Me Down"},
#        {'name': 'Get Back', 'info': 'Cut short by police'}]}]},
#    'info': "The Beatles' last public performance. Band played with Billy Preston on keyboard on top of the roof of the Apple Corp. building. Performances were filmed for the movie 'Let It Be'.",
#    'url': 'https://www.setlist.fm/setlist/the-beatles/1969/apple-corps-rooftop-london-england-53d6f3ad.html'},
#   {'id': '73c18a19',
#    'versionId': '13367d11',
#    'eventDate': '04-09-1968',
#    'lastUpdated': '2020-01-17T01:22:37.000+0000',
#    'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#     'name': 'The Beatles',
#     'sortName': 'Beatles, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#    'venue': {'id': '4bd5973e',
#     'name': 'Twickenham Studios',
#     'city': {'id': '2635308',
#      'name': 'Twickenham',
#      'state': 'England',
#      'stateCode': 'ENG',
#      'coords': {'lat': 51.4333333, 'long': -0.3166667},
#      'country': {'code': 'GB', 'name': 'United Kingdom'}},
#     'url': 'https://www.setlist.fm/venue/twickenham-studios-twickenham-england-4bd5973e.html'},
#    'sets': {'set': [{'name': '"Hey Jude" film sessions',
#       'song': [{'name': "It's the David Frost Theme",
#         'cover': {'mbid': '26fa8b67-6c7f-406c-ad64-a1d070092df2',
#          'name': 'George Martin',
#          'sortName': 'Martin, George',
#          'disambiguation': 'producer, arranger, composer, conductor, audio engineer, and musician',
#          'url': 'https://www.setlist.fm/setlists/george-martin-3d6b92b.html'}},
#        {'name': "It's Now or Never",
#         'cover': {'mbid': '01809552-4f87-45b0-afff-2c6f0730a3be',
#          'name': 'Elvis Presley',
#          'sortName': 'Presley, Elvis',
#          'disambiguation': '“The King of Rock and Roll”',
#          'url': 'https://www.setlist.fm/setlists/elvis-presley-73d6a2b1.html'}},
#        {'name': 'Hey Jude', 'info': 'Take one'},
#        {'name': "It's the David Frost Theme",
#         'cover': {'mbid': '26fa8b67-6c7f-406c-ad64-a1d070092df2',
#          'name': 'George Martin',
#          'sortName': 'Martin, George',
#          'disambiguation': 'producer, arranger, composer, conductor, audio engineer, and musician',
#          'url': 'https://www.setlist.fm/setlists/george-martin-3d6b92b.html'}},
#        {'name': 'Hey Jude', 'info': 'Take two'},
#        {'name': "It's the David Frost Theme",
#         'cover': {'mbid': '26fa8b67-6c7f-406c-ad64-a1d070092df2',
#          'name': 'George Martin',
#          'sortName': 'Martin, George',
#          'disambiguation': 'producer, arranger, composer, conductor, audio engineer, and musician',
#          'url': 'https://www.setlist.fm/setlists/george-martin-3d6b92b.html'}},
#        {'name': 'You Are My Sunshine',
#         'cover': {'mbid': '06ed4e1e-4416-4a7c-b14b-bc68dfd252aa',
#          'name': 'Jimmie Davis',
#          'sortName': 'Davis, Jimmie',
#          'disambiguation': 'American politician, singer and songwriter',
#          'url': 'https://www.setlist.fm/setlists/jimmie-davis-4bd78776.html'}},
#        {'name': 'Hey Jude', 'info': 'Take three'}]},
#      {'name': '"Revolution" film sessions',
#       'song': [{'name': 'Revolution', 'info': 'Only live performance'}]}]},
#    'info': 'Broadcast on September 8th 1968',
#    'url': 'https://www.setlist.fm/setlist/the-beatles/1968/twickenham-studios-twickenham-england-73c18a19.html'},
#   {'id': '43c26b8b',
#    'versionId': 'g2bc1485a',
#    'eventDate': '25-06-1967',
#    'lastUpdated': '2022-02-24T08:01:13.000+0000',
#    'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#     'name': 'The Beatles',
#     'sortName': 'Beatles, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#    'venue': {'id': '43d207b3',
#     'name': 'EMI Recording Studios',
#     'city': {'id': '2643743',
#      'name': 'London',
#      'state': 'England',
#      'stateCode': 'ENG',
#      'coords': {'lat': 51.5084152563931, 'long': -0.125532746315002},
#      'country': {'code': 'GB', 'name': 'United Kingdom'}},
#     'url': 'https://www.setlist.fm/venue/emi-recording-studios-london-england-43d207b3.html'},
#    'sets': {'set': [{'song': [{'name': 'All You Need Is Love'}]}]},
#    'info': "Representing the UK on 'Our World’ the first live, international, satellite television production. With George Martin(piano); Chorus: Jane Asher, Eric Clapton, Hunter Davies, Marianne Faithfull, Patti Harrison, Mick Jagger, Gary Leeds, Mike McCartney, Keith Moon, Graham Nash, Keith Richards; Orchestra conducted by Mike Vickers: Eric Bowie, Jack Emblow, Patrick Halling, Jack Holmes, Don Honeywill, David Mason, Rex Morris, John Ronayne, Lionel Ross, Sidney Sax, Harry Spain, Evan Watkins, Stanley Woods",
#    'url': 'https://www.setlist.fm/setlist/the-beatles/1967/emi-recording-studios-london-england-43c26b8b.html'},
#   {'id': 'bf88dc2',
#    'versionId': '1b3bcd80',
#    'eventDate': '24-06-1967',
#    'lastUpdated': '2020-06-02T08:45:06.000+0000',
#    'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#     'name': 'The Beatles',
#     'sortName': 'Beatles, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#    'venue': {'id': '43d207b3',
#     'name': 'EMI Recording Studios',
#     'city': {'id': '2643743',
#      'name': 'London',
#      'state': 'England',
#      'stateCode': 'ENG',
#      'coords': {'lat': 51.5084152563931, 'long': -0.125532746315002},
#      'country': {'code': 'GB', 'name': 'United Kingdom'}},
#     'url': 'https://www.setlist.fm/venue/emi-recording-studios-london-england-43d207b3.html'},
#    'sets': {'set': [{'song': [{'name': 'All You Need Is Love',
#         'info': 'Live debut'}]}]},
#    'info': 'Open-door rehearsal for the press.',
#    'url': 'https://www.setlist.fm/setlist/the-beatles/1967/emi-recording-studios-london-england-bf88dc2.html'},
#   {'id': '73d67e09',
#    'versionId': '7b069680',
#    'eventDate': '29-08-1966',
#    'lastUpdated': '2019-07-10T19:44:01.000+0000',
#    'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#     'name': 'The Beatles',
#     'sortName': 'Beatles, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#    'venue': {'id': '3bd624d4',
#     'name': 'Candlestick Park',
#     'city': {'id': '5391959',
#      'name': 'San Francisco',
#      'state': 'California',
#      'stateCode': 'CA',
#      'coords': {'lat': 37.775, 'long': -122.419},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/candlestick-park-san-francisco-ca-usa-3bd624d4.html'},
#    'tour': {'name': 'North American Tour 1966'},
#    'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#         'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#          'name': 'Chuck Berry',
#          'sortName': 'Berry, Chuck',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#        {'name': "She's a Woman"},
#        {'name': 'If I Needed Someone'},
#        {'name': 'Day Tripper'},
#        {'name': "Baby's in Black"},
#        {'name': 'I Feel Fine'},
#        {'name': 'Yesterday'},
#        {'name': 'I Wanna Be Your Man'},
#        {'name': 'Nowhere Man'},
#        {'name': 'Paperback Writer'},
#        {'name': 'Long Tall Sally',
#         'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#          'name': 'Little Richard',
#          'sortName': 'Little Richard',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'},
#         'info': 'followed by tease of "In My Life" by John Lennon'}]}]},
#    'info': 'Last public performance until 1969',
#    'url': 'https://www.setlist.fm/setlist/the-beatles/1966/candlestick-park-san-francisco-ca-73d67e09.html'},
#   {'id': '63d67e1f',
#    'versionId': 'g6be47e66',
#    'eventDate': '28-08-1966',
#    'lastUpdated': '2022-11-20T10:28:24.000+0000',
#    'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#     'name': 'The Beatles',
#     'sortName': 'Beatles, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#    'venue': {'id': '1bd63960',
#     'name': 'Dodger Stadium',
#     'city': {'id': '5368361',
#      'name': 'Los Angeles',
#      'state': 'California',
#      'stateCode': 'CA',
#      'coords': {'lat': 34.052, 'long': -118.244},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/dodger-stadium-los-angeles-ca-usa-1bd63960.html'},
#    'tour': {'name': 'North American Tour 1966'},
#    'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#         'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#          'name': 'Chuck Berry',
#          'sortName': 'Berry, Chuck',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#        {'name': "She's a Woman"},
#        {'name': 'If I Needed Someone'},
#        {'name': 'Day Tripper'},
#        {'name': "Baby's in Black"},
#        {'name': 'I Feel Fine'},
#        {'name': 'Yesterday'},
#        {'name': 'I Wanna Be Your Man'},
#        {'name': 'Nowhere Man'},
#        {'name': 'Paperback Writer'},
#        {'name': 'Long Tall Sally',
#         'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#          'name': 'Little Richard',
#          'sortName': 'Little Richard',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#    'url': 'https://www.setlist.fm/setlist/the-beatles/1966/dodger-stadium-los-angeles-ca-63d67e1f.html'},
#   {'id': '13cc41a9',
#    'versionId': '2b873c1a',
#    'eventDate': '25-08-1966',
#    'lastUpdated': '2014-11-16T05:04:59.000+0000',
#    'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#     'name': 'The Beatles',
#     'sortName': 'Beatles, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#    'venue': {'id': '3bd62004',
#     'name': 'Seattle Center Coliseum',
#     'city': {'id': '5809844',
#      'name': 'Seattle',
#      'state': 'Washington',
#      'stateCode': 'WA',
#      'coords': {'lat': 47.6062095, 'long': -122.3320708},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/seattle-center-coliseum-seattle-wa-usa-3bd62004.html'},
#    'tour': {'name': 'North American Tour 1966'},
#    'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#         'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#          'name': 'Chuck Berry',
#          'sortName': 'Berry, Chuck',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#        {'name': "She's a Woman"},
#        {'name': 'If I Needed Someone'},
#        {'name': 'Day Tripper'},
#        {'name': "Baby's in Black"},
#        {'name': 'I Feel Fine'},
#        {'name': 'Yesterday'},
#        {'name': 'I Wanna Be Your Man'},
#        {'name': 'Nowhere Man'},
#        {'name': 'Paperback Writer'},
#        {'name': "I'm Down"}]}]},
#    'info': '3:00PM Show',
#    'url': 'https://www.setlist.fm/setlist/the-beatles/1966/seattle-center-coliseum-seattle-wa-13cc41a9.html'},
#   {'id': '6bd67e1e',
#    'versionId': '33873c21',
#    'eventDate': '25-08-1966',
#    'lastUpdated': '2014-11-16T05:01:45.000+0000',
#    'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#     'name': 'The Beatles',
#     'sortName': 'Beatles, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#    'venue': {'id': '3bd62004',
#     'name': 'Seattle Center Coliseum',
#     'city': {'id': '5809844',
#      'name': 'Seattle',
#      'state': 'Washington',
#      'stateCode': 'WA',
#      'coords': {'lat': 47.6062095, 'long': -122.3320708},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/seattle-center-coliseum-seattle-wa-usa-3bd62004.html'},
#    'tour': {'name': 'North American Tour 1966'},
#    'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#         'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#          'name': 'Chuck Berry',
#          'sortName': 'Berry, Chuck',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#        {'name': "She's a Woman"},
#        {'name': 'If I Needed Someone'},
#        {'name': 'Day Tripper'},
#        {'name': "Baby's in Black"},
#        {'name': 'I Feel Fine'},
#        {'name': 'Yesterday'},
#        {'name': 'I Wanna Be Your Man'},
#        {'name': 'Nowhere Man'},
#        {'name': 'Paperback Writer'},
#        {'name': 'Long Tall Sally',
#         'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#          'name': 'Little Richard',
#          'sortName': 'Little Richard',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#    'info': '8:00PM Show',
#    'url': 'https://www.setlist.fm/setlist/the-beatles/1966/seattle-center-coliseum-seattle-wa-6bd67e1e.html'},
#   {'id': 'bd6bd76',
#    'versionId': '2334c4c3',
#    'eventDate': '23-08-1966',
#    'lastUpdated': '2020-02-05T05:06:05.000+0000',
#    'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#     'name': 'The Beatles',
#     'sortName': 'Beatles, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#    'venue': {'id': 'bd32d42',
#     'name': 'Shea Stadium',
#     'city': {'id': '5133266',
#      'name': 'Queens',
#      'state': 'New York',
#      'stateCode': 'NY',
#      'coords': {'lat': 40.7498243, 'long': -73.7976337},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/shea-stadium-queens-ny-usa-bd32d42.html'},
#    'tour': {'name': 'North American Tour 1966'},
#    'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#         'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#          'name': 'Chuck Berry',
#          'sortName': 'Berry, Chuck',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#        {'name': "She's a Woman"},
#        {'name': 'If I Needed Someone'},
#        {'name': 'Day Tripper'},
#        {'name': "Baby's in Black"},
#        {'name': 'I Feel Fine'},
#        {'name': 'Yesterday'},
#        {'name': 'I Wanna Be Your Man'},
#        {'name': 'Nowhere Man'},
#        {'name': 'Paperback Writer'},
#        {'name': 'Long Tall Sally',
#         'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#          'name': 'Little Richard',
#          'sortName': 'Little Richard',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#    'url': 'https://www.setlist.fm/setlist/the-beatles/1966/shea-stadium-queens-ny-bd6bd76.html'},
#   {'id': '7bd67e1c',
#    'versionId': '3b873c14',
#    'eventDate': '21-08-1966',
#    'lastUpdated': '2014-11-16T05:14:08.000+0000',
#    'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#     'name': 'The Beatles',
#     'sortName': 'Beatles, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#    'venue': {'id': '7bd62618',
#     'name': 'Busch Memorial Stadium',
#     'city': {'id': '4407066',
#      'name': 'St. Louis',
#      'state': 'Missouri',
#      'stateCode': 'MO',
#      'coords': {'lat': 38.6272733, 'long': -90.1978889},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/busch-memorial-stadium-st-louis-mo-usa-7bd62618.html'},
#    'tour': {'name': 'North American Tour 1966'},
#    'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#         'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#          'name': 'Chuck Berry',
#          'sortName': 'Berry, Chuck',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#        {'name': "She's a Woman"},
#        {'name': 'If I Needed Someone'},
#        {'name': 'Day Tripper'},
#        {'name': "Baby's in Black"},
#        {'name': 'I Feel Fine'},
#        {'name': 'Yesterday'},
#        {'name': 'I Wanna Be Your Man'},
#        {'name': 'Nowhere Man'},
#        {'name': 'Paperback Writer'},
#        {'name': 'Long Tall Sally',
#         'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#          'name': 'Little Richard',
#          'sortName': 'Little Richard',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#    'info': '8:30PM Show. The Beatles performed in Cincinnati earlier that day.',
#    'url': 'https://www.setlist.fm/setlist/the-beatles/1966/busch-memorial-stadium-st-louis-mo-7bd67e1c.html'},
#   {'id': '63d67e13',
#    'versionId': '2b873c12',
#    'eventDate': '21-08-1966',
#    'lastUpdated': '2014-11-16T05:11:32.000+0000',
#    'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#     'name': 'The Beatles',
#     'sortName': 'Beatles, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#    'venue': {'id': '13d62d05',
#     'name': 'Crosley Field',
#     'city': {'id': '4508722',
#      'name': 'Cincinnati',
#      'state': 'Ohio',
#      'stateCode': 'OH',
#      'coords': {'lat': 39.1620036, 'long': -84.4568863},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/crosley-field-cincinnati-oh-usa-13d62d05.html'},
#    'tour': {'name': 'North American Tour 1966'},
#    'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#         'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#          'name': 'Chuck Berry',
#          'sortName': 'Berry, Chuck',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#        {'name': "She's a Woman"},
#        {'name': 'If I Needed Someone'},
#        {'name': 'Day Tripper'},
#        {'name': "Baby's in Black"},
#        {'name': 'I Feel Fine'},
#        {'name': 'Yesterday'},
#        {'name': 'I Wanna Be Your Man'},
#        {'name': 'Nowhere Man'},
#        {'name': 'Paperback Writer'},
#        {'name': 'Long Tall Sally',
#         'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#          'name': 'Little Richard',
#          'sortName': 'Little Richard',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#    'info': 'Rescheduled from August 20th. Afternoon Show.',
#    'url': 'https://www.setlist.fm/setlist/the-beatles/1966/crosley-field-cincinnati-oh-63d67e13.html'},
#   {'id': '13cc419d',
#    'versionId': '23873cfb',
#    'eventDate': '19-08-1966',
#    'lastUpdated': '2014-11-16T05:23:20.000+0000',
#    'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#     'name': 'The Beatles',
#     'sortName': 'Beatles, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#    'venue': {'id': '4bd6672a',
#     'name': 'Mid-South Coliseum',
#     'city': {'id': '4641239',
#      'name': 'Memphis',
#      'state': 'Tennessee',
#      'stateCode': 'TN',
#      'coords': {'lat': 35.1495343, 'long': -90.0489801},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/mid-south-coliseum-memphis-tn-usa-4bd6672a.html'},
#    'tour': {'name': 'North American Tour 1966'},
#    'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#         'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#          'name': 'Chuck Berry',
#          'sortName': 'Berry, Chuck',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#        {'name': "She's a Woman"},
#        {'name': 'If I Needed Someone'},
#        {'name': 'Day Tripper'},
#        {'name': "Baby's in Black"},
#        {'name': 'I Feel Fine'},
#        {'name': 'Yesterday'},
#        {'name': 'I Wanna Be Your Man'},
#        {'name': 'Nowhere Man'},
#        {'name': 'Paperback Writer'},
#        {'name': 'Long Tall Sally',
#         'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#          'name': 'Little Richard',
#          'sortName': 'Little Richard',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#    'info': '4:00PM Show',
#    'url': 'https://www.setlist.fm/setlist/the-beatles/1966/mid-south-coliseum-memphis-tn-13cc419d.html'},
#   {'id': '6bd67e12',
#    'versionId': '2b873c06',
#    'eventDate': '19-08-1966',
#    'lastUpdated': '2014-11-16T05:21:21.000+0000',
#    'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#     'name': 'The Beatles',
#     'sortName': 'Beatles, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#    'venue': {'id': '4bd6672a',
#     'name': 'Mid-South Coliseum',
#     'city': {'id': '4641239',
#      'name': 'Memphis',
#      'state': 'Tennessee',
#      'stateCode': 'TN',
#      'coords': {'lat': 35.1495343, 'long': -90.0489801},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/mid-south-coliseum-memphis-tn-usa-4bd6672a.html'},
#    'tour': {'name': 'North American Tour 1966'},
#    'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#         'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#          'name': 'Chuck Berry',
#          'sortName': 'Berry, Chuck',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#        {'name': "She's a Woman"},
#        {'name': 'If I Needed Someone'},
#        {'name': 'Day Tripper'},
#        {'name': "Baby's in Black"},
#        {'name': 'I Feel Fine'},
#        {'name': 'Yesterday'},
#        {'name': 'I Wanna Be Your Man'},
#        {'name': 'Nowhere Man'},
#        {'name': 'Paperback Writer'},
#        {'name': 'Long Tall Sally',
#         'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#          'name': 'Little Richard',
#          'sortName': 'Little Richard',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#    'info': '8:30PM Show',
#    'url': 'https://www.setlist.fm/setlist/the-beatles/1966/mid-south-coliseum-memphis-tn-6bd67e12.html'},
#   {'id': '73d67e11',
#    'versionId': 'g7bf2ba24',
#    'eventDate': '18-08-1966',
#    'lastUpdated': '2022-07-05T18:20:40.000+0000',
#    'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#     'name': 'The Beatles',
#     'sortName': 'Beatles, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#    'venue': {'id': '2bd62482',
#     'name': 'Suffolk Downs',
#     'city': {'id': '4930956',
#      'name': 'Boston',
#      'state': 'Massachusetts',
#      'stateCode': 'MA',
#      'coords': {'lat': 42.3584308, 'long': -71.0597732},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/suffolk-downs-boston-ma-usa-2bd62482.html'},
#    'tour': {'name': 'North American Tour 1966'},
#    'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#         'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#          'name': 'Chuck Berry',
#          'sortName': 'Berry, Chuck',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#        {'name': "She's a Woman"},
#        {'name': 'If I Needed Someone'},
#        {'name': 'Day Tripper'},
#        {'name': "Baby's in Black"},
#        {'name': 'I Feel Fine'},
#        {'name': 'Yesterday'},
#        {'name': 'I Wanna Be Your Man'},
#        {'name': 'Nowhere Man'},
#        {'name': 'Paperback Writer'},
#        {'name': 'Long Tall Sally',
#         'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#          'name': 'Little Richard',
#          'sortName': 'Little Richard',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#    'url': 'https://www.setlist.fm/setlist/the-beatles/1966/suffolk-downs-boston-ma-73d67e11.html'},
#   {'id': '1bcc4194',
#    'versionId': '2b3bfc3e',
#    'eventDate': '17-08-1966',
#    'lastUpdated': '2020-06-02T08:31:39.000+0000',
#    'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#     'name': 'The Beatles',
#     'sortName': 'Beatles, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#    'venue': {'id': '53d63f05',
#     'name': 'Maple Leaf Gardens',
#     'city': {'id': '6167865',
#      'name': 'Toronto',
#      'state': 'Ontario',
#      'stateCode': 'ON',
#      'coords': {'lat': 43.700113788, 'long': -79.416304194},
#      'country': {'code': 'CA', 'name': 'Canada'}},
#     'url': 'https://www.setlist.fm/venue/maple-leaf-gardens-toronto-on-canada-53d63f05.html'},
#    'tour': {'name': 'North American Tour 1966'},
#    'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#         'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#          'name': 'Chuck Berry',
#          'sortName': 'Berry, Chuck',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#        {'name': "She's a Woman"},
#        {'name': 'If I Needed Someone'},
#        {'name': 'Day Tripper'},
#        {'name': "Baby's in Black"},
#        {'name': 'I Feel Fine'},
#        {'name': 'Yesterday'},
#        {'name': 'I Wanna Be Your Man'},
#        {'name': 'Nowhere Man'},
#        {'name': 'Paperback Writer'},
#        {'name': "I'm Down"}]}]},
#    'info': '4:00PM Show',
#    'url': 'https://www.setlist.fm/setlist/the-beatles/1966/maple-leaf-gardens-toronto-on-canada-1bcc4194.html'},
#   {'id': '7bd67e10',
#    'versionId': '2b873cf2',
#    'eventDate': '17-08-1966',
#    'lastUpdated': '2014-11-16T05:27:57.000+0000',
#    'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#     'name': 'The Beatles',
#     'sortName': 'Beatles, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#    'venue': {'id': '53d63f05',
#     'name': 'Maple Leaf Gardens',
#     'city': {'id': '6167865',
#      'name': 'Toronto',
#      'state': 'Ontario',
#      'stateCode': 'ON',
#      'coords': {'lat': 43.700113788, 'long': -79.416304194},
#      'country': {'code': 'CA', 'name': 'Canada'}},
#     'url': 'https://www.setlist.fm/venue/maple-leaf-gardens-toronto-on-canada-53d63f05.html'},
#    'tour': {'name': 'North American Tour 1966'},
#    'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#         'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#          'name': 'Chuck Berry',
#          'sortName': 'Berry, Chuck',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#        {'name': "She's a Woman"},
#        {'name': 'If I Needed Someone'},
#        {'name': 'Day Tripper'},
#        {'name': "Baby's in Black"},
#        {'name': 'I Feel Fine'},
#        {'name': 'Yesterday'},
#        {'name': 'I Wanna Be Your Man'},
#        {'name': 'Nowhere Man'},
#        {'name': 'Paperback Writer'},
#        {'name': 'Long Tall Sally',
#         'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#          'name': 'Little Richard',
#          'sortName': 'Little Richard',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#    'info': '8:00PM Show',
#    'url': 'https://www.setlist.fm/setlist/the-beatles/1966/maple-leaf-gardens-toronto-on-canada-7bd67e10.html'},
#   {'id': '63d67e17',
#    'versionId': 'g7bf2ba30',
#    'eventDate': '16-08-1966',
#    'lastUpdated': '2022-07-05T18:16:02.000+0000',
#    'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#     'name': 'The Beatles',
#     'sortName': 'Beatles, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#    'venue': {'id': '4bd2fbde',
#     'name': 'John F. Kennedy Stadium',
#     'city': {'id': '4560349',
#      'name': 'Philadelphia',
#      'state': 'Pennsylvania',
#      'stateCode': 'PA',
#      'coords': {'lat': 39.952335, 'long': -75.163789},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/john-f-kennedy-stadium-philadelphia-pa-usa-4bd2fbde.html'},
#    'tour': {'name': 'North American Tour 1966'},
#    'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#         'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#          'name': 'Chuck Berry',
#          'sortName': 'Berry, Chuck',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#        {'name': "She's a Woman"},
#        {'name': 'If I Needed Someone'},
#        {'name': 'Day Tripper'},
#        {'name': "Baby's in Black"},
#        {'name': 'I Feel Fine'},
#        {'name': 'Yesterday'},
#        {'name': 'I Wanna Be Your Man'},
#        {'name': 'Nowhere Man'},
#        {'name': 'Paperback Writer'},
#        {'name': 'Long Tall Sally',
#         'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#          'name': 'Little Richard',
#          'sortName': 'Little Richard',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#    'url': 'https://www.setlist.fm/setlist/the-beatles/1966/john-f-kennedy-stadium-philadelphia-pa-63d67e17.html'},
#   {'id': '6bd67e16',
#    'versionId': '1393210d',
#    'eventDate': '15-08-1966',
#    'lastUpdated': '2014-05-31T21:41:18.000+0000',
#    'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#     'name': 'The Beatles',
#     'sortName': 'Beatles, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#    'venue': {'id': '3bd4301c',
#     'name': 'District of Columbia Stadium',
#     'city': {'id': '4140963',
#      'name': 'Washington',
#      'state': 'Washington, D.C.',
#      'stateCode': 'DC',
#      'coords': {'lat': 38.895, 'long': -77.036},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/district-of-columbia-stadium-washington-dc-usa-3bd4301c.html'},
#    'tour': {'name': 'North American Tour 1966'},
#    'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#         'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#          'name': 'Chuck Berry',
#          'sortName': 'Berry, Chuck',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#        {'name': "She's a Woman"},
#        {'name': 'If I Needed Someone'},
#        {'name': 'Day Tripper'},
#        {'name': "Baby's in Black"},
#        {'name': 'I Feel Fine'},
#        {'name': 'Yesterday'},
#        {'name': 'I Wanna Be Your Man'},
#        {'name': 'Nowhere Man'},
#        {'name': 'Paperback Writer'},
#        {'name': 'Long Tall Sally',
#         'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#          'name': 'Little Richard',
#          'sortName': 'Little Richard',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#    'url': 'https://www.setlist.fm/setlist/the-beatles/1966/district-of-columbia-stadium-washington-dc-6bd67e16.html'},
#   {'id': '73d67e15',
#    'versionId': 'be975fa',
#    'eventDate': '14-08-1966',
#    'lastUpdated': '2014-03-06T14:19:16.000+0000',
#    'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#     'name': 'The Beatles',
#     'sortName': 'Beatles, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#    'venue': {'id': '73d626ed',
#     'name': 'Cleveland Stadium',
#     'city': {'id': '5150529',
#      'name': 'Cleveland',
#      'state': 'Ohio',
#      'stateCode': 'OH',
#      'coords': {'lat': 41.4994954, 'long': -81.6954088},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/cleveland-stadium-cleveland-oh-usa-73d626ed.html'},
#    'tour': {'name': 'North American Tour 1966'},
#    'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#         'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#          'name': 'Chuck Berry',
#          'sortName': 'Berry, Chuck',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#        {'name': "She's a Woman"},
#        {'name': 'If I Needed Someone'},
#        {'name': 'Day Tripper'},
#        {'name': 'Rock and Roll Music',
#         'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#          'name': 'Chuck Berry',
#          'sortName': 'Berry, Chuck',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#        {'name': 'I Feel Fine'},
#        {'name': 'Yesterday'},
#        {'name': 'I Wanna Be Your Man'},
#        {'name': 'Nowhere Man'},
#        {'name': 'Paperback Writer'},
#        {'name': 'Long Tall Sally',
#         'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#          'name': 'Little Richard',
#          'sortName': 'Little Richard',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#    'info': 'After a 30 minute delay in the show due to fans rushing the stage, The Beatles dropped "Baby\'s In Black from the set list and performed "Rock And Roll Music" a second time instead to restart the concert.',
#    'url': 'https://www.setlist.fm/setlist/the-beatles/1966/cleveland-stadium-cleveland-oh-73d67e15.html'},
#   {'id': '3bcc4070',
#    'versionId': '33873cc1',
#    'eventDate': '13-08-1966',
#    'lastUpdated': '2014-11-16T05:46:23.000+0000',
#    'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#     'name': 'The Beatles',
#     'sortName': 'Beatles, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#    'venue': {'id': '63d62657',
#     'name': 'Olympia Stadium',
#     'city': {'id': '4990729',
#      'name': 'Detroit',
#      'state': 'Michigan',
#      'stateCode': 'MI',
#      'coords': {'lat': 42.331427, 'long': -83.0457538},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/olympia-stadium-detroit-mi-usa-63d62657.html'},
#    'tour': {'name': 'North American Tour 1966'},
#    'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#         'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#          'name': 'Chuck Berry',
#          'sortName': 'Berry, Chuck',
#          'disambiguation': '',
#          'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#        {'name': "She's a Woman"},
#        {'name': 'If I Needed Someone'},
#        {'name': 'Day Tripper'},
#        {'name': "Baby's in Black"},
#        {'name': 'I Feel Fine'},
#        {'name': 'Yesterday'},
#        {'name': 'I Wanna Be Your Man'},
#        {'name': 'Nowhere Man'},
#        {'name': 'Paperback Writer'},
#        {'name': "I'm Down"}]}]},
#    'info': '2:00PM Show',
#    'url': 'https://www.setlist.fm/setlist/the-beatles/1966/olympia-stadium-detroit-mi-3bcc4070.html'}]}

# %%
# response.json()['businesses']

b.json()['setlist']
# Out:
# [{'id': '53d6f3ad',
#   'versionId': 'g53c29b9d',
#   'eventDate': '30-01-1969',
#   'lastUpdated': '2021-12-14T08:26:08.000+0000',
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#    'name': 'The Beatles',
#    'sortName': 'Beatles, The',
#    'disambiguation': '',
#    'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#   'venue': {'id': '4bd627fe',
#    'name': 'Apple Corps Rooftop',
#    'city': {'id': '2643743',
#     'name': 'London',
#     'state': 'England',
#     'stateCode': 'ENG',
#     'coords': {'lat': 51.5084152563931, 'long': -0.125532746315002},
#     'country': {'code': 'GB', 'name': 'United Kingdom'}},
#    'url': 'https://www.setlist.fm/venue/apple-corps-rooftop-london-england-4bd627fe.html'},
#   'sets': {'set': [{'song': [{'name': 'Get Back'},
#       {'name': 'Get Back'},
#       {'name': "Don't Let Me Down"},
#       {'name': "I've Got a Feeling"},
#       {'name': 'One After 909', 'info': 'with "Danny Boy" tease'},
#       {'name': 'Dig a Pony', 'info': 'with a false start'},
#       {'name': 'God Save the Queen',
#        'cover': {'mbid': '9be7f096-97ec-4615-8957-8d40b5dcbc41',
#         'name': '[traditional]',
#         'sortName': '[traditional]',
#         'disambiguation': 'Special Purpose Artist',
#         'url': 'https://www.setlist.fm/setlists/traditional-5bd2f7e4.html'},
#        'info': 'Jam'},
#       {'name': "I've Got a Feeling",
#        'info': 'with "A Pretty Girl Is Like a Melody" tease'},
#       {'name': "Don't Let Me Down"},
#       {'name': 'Get Back', 'info': 'Cut short by police'}]}]},
#   'info': "The Beatles' last public performance. Band played with Billy Preston on keyboard on top of the roof of the Apple Corp. building. Performances were filmed for the movie 'Let It Be'.",
#   'url': 'https://www.setlist.fm/setlist/the-beatles/1969/apple-corps-rooftop-london-england-53d6f3ad.html'},
#  {'id': '73c18a19',
#   'versionId': '13367d11',
#   'eventDate': '04-09-1968',
#   'lastUpdated': '2020-01-17T01:22:37.000+0000',
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#    'name': 'The Beatles',
#    'sortName': 'Beatles, The',
#    'disambiguation': '',
#    'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#   'venue': {'id': '4bd5973e',
#    'name': 'Twickenham Studios',
#    'city': {'id': '2635308',
#     'name': 'Twickenham',
#     'state': 'England',
#     'stateCode': 'ENG',
#     'coords': {'lat': 51.4333333, 'long': -0.3166667},
#     'country': {'code': 'GB', 'name': 'United Kingdom'}},
#    'url': 'https://www.setlist.fm/venue/twickenham-studios-twickenham-england-4bd5973e.html'},
#   'sets': {'set': [{'name': '"Hey Jude" film sessions',
#      'song': [{'name': "It's the David Frost Theme",
#        'cover': {'mbid': '26fa8b67-6c7f-406c-ad64-a1d070092df2',
#         'name': 'George Martin',
#         'sortName': 'Martin, George',
#         'disambiguation': 'producer, arranger, composer, conductor, audio engineer, and musician',
#         'url': 'https://www.setlist.fm/setlists/george-martin-3d6b92b.html'}},
#       {'name': "It's Now or Never",
#        'cover': {'mbid': '01809552-4f87-45b0-afff-2c6f0730a3be',
#         'name': 'Elvis Presley',
#         'sortName': 'Presley, Elvis',
#         'disambiguation': '“The King of Rock and Roll”',
#         'url': 'https://www.setlist.fm/setlists/elvis-presley-73d6a2b1.html'}},
#       {'name': 'Hey Jude', 'info': 'Take one'},
#       {'name': "It's the David Frost Theme",
#        'cover': {'mbid': '26fa8b67-6c7f-406c-ad64-a1d070092df2',
#         'name': 'George Martin',
#         'sortName': 'Martin, George',
#         'disambiguation': 'producer, arranger, composer, conductor, audio engineer, and musician',
#         'url': 'https://www.setlist.fm/setlists/george-martin-3d6b92b.html'}},
#       {'name': 'Hey Jude', 'info': 'Take two'},
#       {'name': "It's the David Frost Theme",
#        'cover': {'mbid': '26fa8b67-6c7f-406c-ad64-a1d070092df2',
#         'name': 'George Martin',
#         'sortName': 'Martin, George',
#         'disambiguation': 'producer, arranger, composer, conductor, audio engineer, and musician',
#         'url': 'https://www.setlist.fm/setlists/george-martin-3d6b92b.html'}},
#       {'name': 'You Are My Sunshine',
#        'cover': {'mbid': '06ed4e1e-4416-4a7c-b14b-bc68dfd252aa',
#         'name': 'Jimmie Davis',
#         'sortName': 'Davis, Jimmie',
#         'disambiguation': 'American politician, singer and songwriter',
#         'url': 'https://www.setlist.fm/setlists/jimmie-davis-4bd78776.html'}},
#       {'name': 'Hey Jude', 'info': 'Take three'}]},
#     {'name': '"Revolution" film sessions',
#      'song': [{'name': 'Revolution', 'info': 'Only live performance'}]}]},
#   'info': 'Broadcast on September 8th 1968',
#   'url': 'https://www.setlist.fm/setlist/the-beatles/1968/twickenham-studios-twickenham-england-73c18a19.html'},
#  {'id': '43c26b8b',
#   'versionId': 'g2bc1485a',
#   'eventDate': '25-06-1967',
#   'lastUpdated': '2022-02-24T08:01:13.000+0000',
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#    'name': 'The Beatles',
#    'sortName': 'Beatles, The',
#    'disambiguation': '',
#    'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#   'venue': {'id': '43d207b3',
#    'name': 'EMI Recording Studios',
#    'city': {'id': '2643743',
#     'name': 'London',
#     'state': 'England',
#     'stateCode': 'ENG',
#     'coords': {'lat': 51.5084152563931, 'long': -0.125532746315002},
#     'country': {'code': 'GB', 'name': 'United Kingdom'}},
#    'url': 'https://www.setlist.fm/venue/emi-recording-studios-london-england-43d207b3.html'},
#   'sets': {'set': [{'song': [{'name': 'All You Need Is Love'}]}]},
#   'info': "Representing the UK on 'Our World’ the first live, international, satellite television production. With George Martin(piano); Chorus: Jane Asher, Eric Clapton, Hunter Davies, Marianne Faithfull, Patti Harrison, Mick Jagger, Gary Leeds, Mike McCartney, Keith Moon, Graham Nash, Keith Richards; Orchestra conducted by Mike Vickers: Eric Bowie, Jack Emblow, Patrick Halling, Jack Holmes, Don Honeywill, David Mason, Rex Morris, John Ronayne, Lionel Ross, Sidney Sax, Harry Spain, Evan Watkins, Stanley Woods",
#   'url': 'https://www.setlist.fm/setlist/the-beatles/1967/emi-recording-studios-london-england-43c26b8b.html'},
#  {'id': 'bf88dc2',
#   'versionId': '1b3bcd80',
#   'eventDate': '24-06-1967',
#   'lastUpdated': '2020-06-02T08:45:06.000+0000',
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#    'name': 'The Beatles',
#    'sortName': 'Beatles, The',
#    'disambiguation': '',
#    'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#   'venue': {'id': '43d207b3',
#    'name': 'EMI Recording Studios',
#    'city': {'id': '2643743',
#     'name': 'London',
#     'state': 'England',
#     'stateCode': 'ENG',
#     'coords': {'lat': 51.5084152563931, 'long': -0.125532746315002},
#     'country': {'code': 'GB', 'name': 'United Kingdom'}},
#    'url': 'https://www.setlist.fm/venue/emi-recording-studios-london-england-43d207b3.html'},
#   'sets': {'set': [{'song': [{'name': 'All You Need Is Love',
#        'info': 'Live debut'}]}]},
#   'info': 'Open-door rehearsal for the press.',
#   'url': 'https://www.setlist.fm/setlist/the-beatles/1967/emi-recording-studios-london-england-bf88dc2.html'},
#  {'id': '73d67e09',
#   'versionId': '7b069680',
#   'eventDate': '29-08-1966',
#   'lastUpdated': '2019-07-10T19:44:01.000+0000',
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#    'name': 'The Beatles',
#    'sortName': 'Beatles, The',
#    'disambiguation': '',
#    'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#   'venue': {'id': '3bd624d4',
#    'name': 'Candlestick Park',
#    'city': {'id': '5391959',
#     'name': 'San Francisco',
#     'state': 'California',
#     'stateCode': 'CA',
#     'coords': {'lat': 37.775, 'long': -122.419},
#     'country': {'code': 'US', 'name': 'United States'}},
#    'url': 'https://www.setlist.fm/venue/candlestick-park-san-francisco-ca-usa-3bd624d4.html'},
#   'tour': {'name': 'North American Tour 1966'},
#   'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#        'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#         'name': 'Chuck Berry',
#         'sortName': 'Berry, Chuck',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#       {'name': "She's a Woman"},
#       {'name': 'If I Needed Someone'},
#       {'name': 'Day Tripper'},
#       {'name': "Baby's in Black"},
#       {'name': 'I Feel Fine'},
#       {'name': 'Yesterday'},
#       {'name': 'I Wanna Be Your Man'},
#       {'name': 'Nowhere Man'},
#       {'name': 'Paperback Writer'},
#       {'name': 'Long Tall Sally',
#        'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#         'name': 'Little Richard',
#         'sortName': 'Little Richard',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'},
#        'info': 'followed by tease of "In My Life" by John Lennon'}]}]},
#   'info': 'Last public performance until 1969',
#   'url': 'https://www.setlist.fm/setlist/the-beatles/1966/candlestick-park-san-francisco-ca-73d67e09.html'},
#  {'id': '63d67e1f',
#   'versionId': 'g6be47e66',
#   'eventDate': '28-08-1966',
#   'lastUpdated': '2022-11-20T10:28:24.000+0000',
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#    'name': 'The Beatles',
#    'sortName': 'Beatles, The',
#    'disambiguation': '',
#    'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#   'venue': {'id': '1bd63960',
#    'name': 'Dodger Stadium',
#    'city': {'id': '5368361',
#     'name': 'Los Angeles',
#     'state': 'California',
#     'stateCode': 'CA',
#     'coords': {'lat': 34.052, 'long': -118.244},
#     'country': {'code': 'US', 'name': 'United States'}},
#    'url': 'https://www.setlist.fm/venue/dodger-stadium-los-angeles-ca-usa-1bd63960.html'},
#   'tour': {'name': 'North American Tour 1966'},
#   'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#        'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#         'name': 'Chuck Berry',
#         'sortName': 'Berry, Chuck',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#       {'name': "She's a Woman"},
#       {'name': 'If I Needed Someone'},
#       {'name': 'Day Tripper'},
#       {'name': "Baby's in Black"},
#       {'name': 'I Feel Fine'},
#       {'name': 'Yesterday'},
#       {'name': 'I Wanna Be Your Man'},
#       {'name': 'Nowhere Man'},
#       {'name': 'Paperback Writer'},
#       {'name': 'Long Tall Sally',
#        'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#         'name': 'Little Richard',
#         'sortName': 'Little Richard',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#   'url': 'https://www.setlist.fm/setlist/the-beatles/1966/dodger-stadium-los-angeles-ca-63d67e1f.html'},
#  {'id': '13cc41a9',
#   'versionId': '2b873c1a',
#   'eventDate': '25-08-1966',
#   'lastUpdated': '2014-11-16T05:04:59.000+0000',
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#    'name': 'The Beatles',
#    'sortName': 'Beatles, The',
#    'disambiguation': '',
#    'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#   'venue': {'id': '3bd62004',
#    'name': 'Seattle Center Coliseum',
#    'city': {'id': '5809844',
#     'name': 'Seattle',
#     'state': 'Washington',
#     'stateCode': 'WA',
#     'coords': {'lat': 47.6062095, 'long': -122.3320708},
#     'country': {'code': 'US', 'name': 'United States'}},
#    'url': 'https://www.setlist.fm/venue/seattle-center-coliseum-seattle-wa-usa-3bd62004.html'},
#   'tour': {'name': 'North American Tour 1966'},
#   'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#        'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#         'name': 'Chuck Berry',
#         'sortName': 'Berry, Chuck',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#       {'name': "She's a Woman"},
#       {'name': 'If I Needed Someone'},
#       {'name': 'Day Tripper'},
#       {'name': "Baby's in Black"},
#       {'name': 'I Feel Fine'},
#       {'name': 'Yesterday'},
#       {'name': 'I Wanna Be Your Man'},
#       {'name': 'Nowhere Man'},
#       {'name': 'Paperback Writer'},
#       {'name': "I'm Down"}]}]},
#   'info': '3:00PM Show',
#   'url': 'https://www.setlist.fm/setlist/the-beatles/1966/seattle-center-coliseum-seattle-wa-13cc41a9.html'},
#  {'id': '6bd67e1e',
#   'versionId': '33873c21',
#   'eventDate': '25-08-1966',
#   'lastUpdated': '2014-11-16T05:01:45.000+0000',
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#    'name': 'The Beatles',
#    'sortName': 'Beatles, The',
#    'disambiguation': '',
#    'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#   'venue': {'id': '3bd62004',
#    'name': 'Seattle Center Coliseum',
#    'city': {'id': '5809844',
#     'name': 'Seattle',
#     'state': 'Washington',
#     'stateCode': 'WA',
#     'coords': {'lat': 47.6062095, 'long': -122.3320708},
#     'country': {'code': 'US', 'name': 'United States'}},
#    'url': 'https://www.setlist.fm/venue/seattle-center-coliseum-seattle-wa-usa-3bd62004.html'},
#   'tour': {'name': 'North American Tour 1966'},
#   'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#        'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#         'name': 'Chuck Berry',
#         'sortName': 'Berry, Chuck',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#       {'name': "She's a Woman"},
#       {'name': 'If I Needed Someone'},
#       {'name': 'Day Tripper'},
#       {'name': "Baby's in Black"},
#       {'name': 'I Feel Fine'},
#       {'name': 'Yesterday'},
#       {'name': 'I Wanna Be Your Man'},
#       {'name': 'Nowhere Man'},
#       {'name': 'Paperback Writer'},
#       {'name': 'Long Tall Sally',
#        'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#         'name': 'Little Richard',
#         'sortName': 'Little Richard',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#   'info': '8:00PM Show',
#   'url': 'https://www.setlist.fm/setlist/the-beatles/1966/seattle-center-coliseum-seattle-wa-6bd67e1e.html'},
#  {'id': 'bd6bd76',
#   'versionId': '2334c4c3',
#   'eventDate': '23-08-1966',
#   'lastUpdated': '2020-02-05T05:06:05.000+0000',
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#    'name': 'The Beatles',
#    'sortName': 'Beatles, The',
#    'disambiguation': '',
#    'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#   'venue': {'id': 'bd32d42',
#    'name': 'Shea Stadium',
#    'city': {'id': '5133266',
#     'name': 'Queens',
#     'state': 'New York',
#     'stateCode': 'NY',
#     'coords': {'lat': 40.7498243, 'long': -73.7976337},
#     'country': {'code': 'US', 'name': 'United States'}},
#    'url': 'https://www.setlist.fm/venue/shea-stadium-queens-ny-usa-bd32d42.html'},
#   'tour': {'name': 'North American Tour 1966'},
#   'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#        'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#         'name': 'Chuck Berry',
#         'sortName': 'Berry, Chuck',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#       {'name': "She's a Woman"},
#       {'name': 'If I Needed Someone'},
#       {'name': 'Day Tripper'},
#       {'name': "Baby's in Black"},
#       {'name': 'I Feel Fine'},
#       {'name': 'Yesterday'},
#       {'name': 'I Wanna Be Your Man'},
#       {'name': 'Nowhere Man'},
#       {'name': 'Paperback Writer'},
#       {'name': 'Long Tall Sally',
#        'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#         'name': 'Little Richard',
#         'sortName': 'Little Richard',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#   'url': 'https://www.setlist.fm/setlist/the-beatles/1966/shea-stadium-queens-ny-bd6bd76.html'},
#  {'id': '7bd67e1c',
#   'versionId': '3b873c14',
#   'eventDate': '21-08-1966',
#   'lastUpdated': '2014-11-16T05:14:08.000+0000',
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#    'name': 'The Beatles',
#    'sortName': 'Beatles, The',
#    'disambiguation': '',
#    'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#   'venue': {'id': '7bd62618',
#    'name': 'Busch Memorial Stadium',
#    'city': {'id': '4407066',
#     'name': 'St. Louis',
#     'state': 'Missouri',
#     'stateCode': 'MO',
#     'coords': {'lat': 38.6272733, 'long': -90.1978889},
#     'country': {'code': 'US', 'name': 'United States'}},
#    'url': 'https://www.setlist.fm/venue/busch-memorial-stadium-st-louis-mo-usa-7bd62618.html'},
#   'tour': {'name': 'North American Tour 1966'},
#   'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#        'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#         'name': 'Chuck Berry',
#         'sortName': 'Berry, Chuck',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#       {'name': "She's a Woman"},
#       {'name': 'If I Needed Someone'},
#       {'name': 'Day Tripper'},
#       {'name': "Baby's in Black"},
#       {'name': 'I Feel Fine'},
#       {'name': 'Yesterday'},
#       {'name': 'I Wanna Be Your Man'},
#       {'name': 'Nowhere Man'},
#       {'name': 'Paperback Writer'},
#       {'name': 'Long Tall Sally',
#        'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#         'name': 'Little Richard',
#         'sortName': 'Little Richard',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#   'info': '8:30PM Show. The Beatles performed in Cincinnati earlier that day.',
#   'url': 'https://www.setlist.fm/setlist/the-beatles/1966/busch-memorial-stadium-st-louis-mo-7bd67e1c.html'},
#  {'id': '63d67e13',
#   'versionId': '2b873c12',
#   'eventDate': '21-08-1966',
#   'lastUpdated': '2014-11-16T05:11:32.000+0000',
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#    'name': 'The Beatles',
#    'sortName': 'Beatles, The',
#    'disambiguation': '',
#    'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#   'venue': {'id': '13d62d05',
#    'name': 'Crosley Field',
#    'city': {'id': '4508722',
#     'name': 'Cincinnati',
#     'state': 'Ohio',
#     'stateCode': 'OH',
#     'coords': {'lat': 39.1620036, 'long': -84.4568863},
#     'country': {'code': 'US', 'name': 'United States'}},
#    'url': 'https://www.setlist.fm/venue/crosley-field-cincinnati-oh-usa-13d62d05.html'},
#   'tour': {'name': 'North American Tour 1966'},
#   'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#        'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#         'name': 'Chuck Berry',
#         'sortName': 'Berry, Chuck',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#       {'name': "She's a Woman"},
#       {'name': 'If I Needed Someone'},
#       {'name': 'Day Tripper'},
#       {'name': "Baby's in Black"},
#       {'name': 'I Feel Fine'},
#       {'name': 'Yesterday'},
#       {'name': 'I Wanna Be Your Man'},
#       {'name': 'Nowhere Man'},
#       {'name': 'Paperback Writer'},
#       {'name': 'Long Tall Sally',
#        'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#         'name': 'Little Richard',
#         'sortName': 'Little Richard',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#   'info': 'Rescheduled from August 20th. Afternoon Show.',
#   'url': 'https://www.setlist.fm/setlist/the-beatles/1966/crosley-field-cincinnati-oh-63d67e13.html'},
#  {'id': '13cc419d',
#   'versionId': '23873cfb',
#   'eventDate': '19-08-1966',
#   'lastUpdated': '2014-11-16T05:23:20.000+0000',
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#    'name': 'The Beatles',
#    'sortName': 'Beatles, The',
#    'disambiguation': '',
#    'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#   'venue': {'id': '4bd6672a',
#    'name': 'Mid-South Coliseum',
#    'city': {'id': '4641239',
#     'name': 'Memphis',
#     'state': 'Tennessee',
#     'stateCode': 'TN',
#     'coords': {'lat': 35.1495343, 'long': -90.0489801},
#     'country': {'code': 'US', 'name': 'United States'}},
#    'url': 'https://www.setlist.fm/venue/mid-south-coliseum-memphis-tn-usa-4bd6672a.html'},
#   'tour': {'name': 'North American Tour 1966'},
#   'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#        'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#         'name': 'Chuck Berry',
#         'sortName': 'Berry, Chuck',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#       {'name': "She's a Woman"},
#       {'name': 'If I Needed Someone'},
#       {'name': 'Day Tripper'},
#       {'name': "Baby's in Black"},
#       {'name': 'I Feel Fine'},
#       {'name': 'Yesterday'},
#       {'name': 'I Wanna Be Your Man'},
#       {'name': 'Nowhere Man'},
#       {'name': 'Paperback Writer'},
#       {'name': 'Long Tall Sally',
#        'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#         'name': 'Little Richard',
#         'sortName': 'Little Richard',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#   'info': '4:00PM Show',
#   'url': 'https://www.setlist.fm/setlist/the-beatles/1966/mid-south-coliseum-memphis-tn-13cc419d.html'},
#  {'id': '6bd67e12',
#   'versionId': '2b873c06',
#   'eventDate': '19-08-1966',
#   'lastUpdated': '2014-11-16T05:21:21.000+0000',
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#    'name': 'The Beatles',
#    'sortName': 'Beatles, The',
#    'disambiguation': '',
#    'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#   'venue': {'id': '4bd6672a',
#    'name': 'Mid-South Coliseum',
#    'city': {'id': '4641239',
#     'name': 'Memphis',
#     'state': 'Tennessee',
#     'stateCode': 'TN',
#     'coords': {'lat': 35.1495343, 'long': -90.0489801},
#     'country': {'code': 'US', 'name': 'United States'}},
#    'url': 'https://www.setlist.fm/venue/mid-south-coliseum-memphis-tn-usa-4bd6672a.html'},
#   'tour': {'name': 'North American Tour 1966'},
#   'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#        'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#         'name': 'Chuck Berry',
#         'sortName': 'Berry, Chuck',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#       {'name': "She's a Woman"},
#       {'name': 'If I Needed Someone'},
#       {'name': 'Day Tripper'},
#       {'name': "Baby's in Black"},
#       {'name': 'I Feel Fine'},
#       {'name': 'Yesterday'},
#       {'name': 'I Wanna Be Your Man'},
#       {'name': 'Nowhere Man'},
#       {'name': 'Paperback Writer'},
#       {'name': 'Long Tall Sally',
#        'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#         'name': 'Little Richard',
#         'sortName': 'Little Richard',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#   'info': '8:30PM Show',
#   'url': 'https://www.setlist.fm/setlist/the-beatles/1966/mid-south-coliseum-memphis-tn-6bd67e12.html'},
#  {'id': '73d67e11',
#   'versionId': 'g7bf2ba24',
#   'eventDate': '18-08-1966',
#   'lastUpdated': '2022-07-05T18:20:40.000+0000',
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#    'name': 'The Beatles',
#    'sortName': 'Beatles, The',
#    'disambiguation': '',
#    'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#   'venue': {'id': '2bd62482',
#    'name': 'Suffolk Downs',
#    'city': {'id': '4930956',
#     'name': 'Boston',
#     'state': 'Massachusetts',
#     'stateCode': 'MA',
#     'coords': {'lat': 42.3584308, 'long': -71.0597732},
#     'country': {'code': 'US', 'name': 'United States'}},
#    'url': 'https://www.setlist.fm/venue/suffolk-downs-boston-ma-usa-2bd62482.html'},
#   'tour': {'name': 'North American Tour 1966'},
#   'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#        'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#         'name': 'Chuck Berry',
#         'sortName': 'Berry, Chuck',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#       {'name': "She's a Woman"},
#       {'name': 'If I Needed Someone'},
#       {'name': 'Day Tripper'},
#       {'name': "Baby's in Black"},
#       {'name': 'I Feel Fine'},
#       {'name': 'Yesterday'},
#       {'name': 'I Wanna Be Your Man'},
#       {'name': 'Nowhere Man'},
#       {'name': 'Paperback Writer'},
#       {'name': 'Long Tall Sally',
#        'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#         'name': 'Little Richard',
#         'sortName': 'Little Richard',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#   'url': 'https://www.setlist.fm/setlist/the-beatles/1966/suffolk-downs-boston-ma-73d67e11.html'},
#  {'id': '1bcc4194',
#   'versionId': '2b3bfc3e',
#   'eventDate': '17-08-1966',
#   'lastUpdated': '2020-06-02T08:31:39.000+0000',
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#    'name': 'The Beatles',
#    'sortName': 'Beatles, The',
#    'disambiguation': '',
#    'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#   'venue': {'id': '53d63f05',
#    'name': 'Maple Leaf Gardens',
#    'city': {'id': '6167865',
#     'name': 'Toronto',
#     'state': 'Ontario',
#     'stateCode': 'ON',
#     'coords': {'lat': 43.700113788, 'long': -79.416304194},
#     'country': {'code': 'CA', 'name': 'Canada'}},
#    'url': 'https://www.setlist.fm/venue/maple-leaf-gardens-toronto-on-canada-53d63f05.html'},
#   'tour': {'name': 'North American Tour 1966'},
#   'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#        'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#         'name': 'Chuck Berry',
#         'sortName': 'Berry, Chuck',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#       {'name': "She's a Woman"},
#       {'name': 'If I Needed Someone'},
#       {'name': 'Day Tripper'},
#       {'name': "Baby's in Black"},
#       {'name': 'I Feel Fine'},
#       {'name': 'Yesterday'},
#       {'name': 'I Wanna Be Your Man'},
#       {'name': 'Nowhere Man'},
#       {'name': 'Paperback Writer'},
#       {'name': "I'm Down"}]}]},
#   'info': '4:00PM Show',
#   'url': 'https://www.setlist.fm/setlist/the-beatles/1966/maple-leaf-gardens-toronto-on-canada-1bcc4194.html'},
#  {'id': '7bd67e10',
#   'versionId': '2b873cf2',
#   'eventDate': '17-08-1966',
#   'lastUpdated': '2014-11-16T05:27:57.000+0000',
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#    'name': 'The Beatles',
#    'sortName': 'Beatles, The',
#    'disambiguation': '',
#    'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#   'venue': {'id': '53d63f05',
#    'name': 'Maple Leaf Gardens',
#    'city': {'id': '6167865',
#     'name': 'Toronto',
#     'state': 'Ontario',
#     'stateCode': 'ON',
#     'coords': {'lat': 43.700113788, 'long': -79.416304194},
#     'country': {'code': 'CA', 'name': 'Canada'}},
#    'url': 'https://www.setlist.fm/venue/maple-leaf-gardens-toronto-on-canada-53d63f05.html'},
#   'tour': {'name': 'North American Tour 1966'},
#   'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#        'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#         'name': 'Chuck Berry',
#         'sortName': 'Berry, Chuck',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#       {'name': "She's a Woman"},
#       {'name': 'If I Needed Someone'},
#       {'name': 'Day Tripper'},
#       {'name': "Baby's in Black"},
#       {'name': 'I Feel Fine'},
#       {'name': 'Yesterday'},
#       {'name': 'I Wanna Be Your Man'},
#       {'name': 'Nowhere Man'},
#       {'name': 'Paperback Writer'},
#       {'name': 'Long Tall Sally',
#        'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#         'name': 'Little Richard',
#         'sortName': 'Little Richard',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#   'info': '8:00PM Show',
#   'url': 'https://www.setlist.fm/setlist/the-beatles/1966/maple-leaf-gardens-toronto-on-canada-7bd67e10.html'},
#  {'id': '63d67e17',
#   'versionId': 'g7bf2ba30',
#   'eventDate': '16-08-1966',
#   'lastUpdated': '2022-07-05T18:16:02.000+0000',
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#    'name': 'The Beatles',
#    'sortName': 'Beatles, The',
#    'disambiguation': '',
#    'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#   'venue': {'id': '4bd2fbde',
#    'name': 'John F. Kennedy Stadium',
#    'city': {'id': '4560349',
#     'name': 'Philadelphia',
#     'state': 'Pennsylvania',
#     'stateCode': 'PA',
#     'coords': {'lat': 39.952335, 'long': -75.163789},
#     'country': {'code': 'US', 'name': 'United States'}},
#    'url': 'https://www.setlist.fm/venue/john-f-kennedy-stadium-philadelphia-pa-usa-4bd2fbde.html'},
#   'tour': {'name': 'North American Tour 1966'},
#   'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#        'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#         'name': 'Chuck Berry',
#         'sortName': 'Berry, Chuck',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#       {'name': "She's a Woman"},
#       {'name': 'If I Needed Someone'},
#       {'name': 'Day Tripper'},
#       {'name': "Baby's in Black"},
#       {'name': 'I Feel Fine'},
#       {'name': 'Yesterday'},
#       {'name': 'I Wanna Be Your Man'},
#       {'name': 'Nowhere Man'},
#       {'name': 'Paperback Writer'},
#       {'name': 'Long Tall Sally',
#        'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#         'name': 'Little Richard',
#         'sortName': 'Little Richard',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#   'url': 'https://www.setlist.fm/setlist/the-beatles/1966/john-f-kennedy-stadium-philadelphia-pa-63d67e17.html'},
#  {'id': '6bd67e16',
#   'versionId': '1393210d',
#   'eventDate': '15-08-1966',
#   'lastUpdated': '2014-05-31T21:41:18.000+0000',
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#    'name': 'The Beatles',
#    'sortName': 'Beatles, The',
#    'disambiguation': '',
#    'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#   'venue': {'id': '3bd4301c',
#    'name': 'District of Columbia Stadium',
#    'city': {'id': '4140963',
#     'name': 'Washington',
#     'state': 'Washington, D.C.',
#     'stateCode': 'DC',
#     'coords': {'lat': 38.895, 'long': -77.036},
#     'country': {'code': 'US', 'name': 'United States'}},
#    'url': 'https://www.setlist.fm/venue/district-of-columbia-stadium-washington-dc-usa-3bd4301c.html'},
#   'tour': {'name': 'North American Tour 1966'},
#   'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#        'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#         'name': 'Chuck Berry',
#         'sortName': 'Berry, Chuck',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#       {'name': "She's a Woman"},
#       {'name': 'If I Needed Someone'},
#       {'name': 'Day Tripper'},
#       {'name': "Baby's in Black"},
#       {'name': 'I Feel Fine'},
#       {'name': 'Yesterday'},
#       {'name': 'I Wanna Be Your Man'},
#       {'name': 'Nowhere Man'},
#       {'name': 'Paperback Writer'},
#       {'name': 'Long Tall Sally',
#        'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#         'name': 'Little Richard',
#         'sortName': 'Little Richard',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#   'url': 'https://www.setlist.fm/setlist/the-beatles/1966/district-of-columbia-stadium-washington-dc-6bd67e16.html'},
#  {'id': '73d67e15',
#   'versionId': 'be975fa',
#   'eventDate': '14-08-1966',
#   'lastUpdated': '2014-03-06T14:19:16.000+0000',
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#    'name': 'The Beatles',
#    'sortName': 'Beatles, The',
#    'disambiguation': '',
#    'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#   'venue': {'id': '73d626ed',
#    'name': 'Cleveland Stadium',
#    'city': {'id': '5150529',
#     'name': 'Cleveland',
#     'state': 'Ohio',
#     'stateCode': 'OH',
#     'coords': {'lat': 41.4994954, 'long': -81.6954088},
#     'country': {'code': 'US', 'name': 'United States'}},
#    'url': 'https://www.setlist.fm/venue/cleveland-stadium-cleveland-oh-usa-73d626ed.html'},
#   'tour': {'name': 'North American Tour 1966'},
#   'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#        'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#         'name': 'Chuck Berry',
#         'sortName': 'Berry, Chuck',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#       {'name': "She's a Woman"},
#       {'name': 'If I Needed Someone'},
#       {'name': 'Day Tripper'},
#       {'name': 'Rock and Roll Music',
#        'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#         'name': 'Chuck Berry',
#         'sortName': 'Berry, Chuck',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#       {'name': 'I Feel Fine'},
#       {'name': 'Yesterday'},
#       {'name': 'I Wanna Be Your Man'},
#       {'name': 'Nowhere Man'},
#       {'name': 'Paperback Writer'},
#       {'name': 'Long Tall Sally',
#        'cover': {'mbid': '95c2339b-8277-49a6-9aaf-08d8eeeaa0be',
#         'name': 'Little Richard',
#         'sortName': 'Little Richard',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/little-richard-4bd6af2e.html'}}]}]},
#   'info': 'After a 30 minute delay in the show due to fans rushing the stage, The Beatles dropped "Baby\'s In Black from the set list and performed "Rock And Roll Music" a second time instead to restart the concert.',
#   'url': 'https://www.setlist.fm/setlist/the-beatles/1966/cleveland-stadium-cleveland-oh-73d67e15.html'},
#  {'id': '3bcc4070',
#   'versionId': '33873cc1',
#   'eventDate': '13-08-1966',
#   'lastUpdated': '2014-11-16T05:46:23.000+0000',
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#    'name': 'The Beatles',
#    'sortName': 'Beatles, The',
#    'disambiguation': '',
#    'url': 'https://www.setlist.fm/setlists/the-beatles-23d6a88b.html'},
#   'venue': {'id': '63d62657',
#    'name': 'Olympia Stadium',
#    'city': {'id': '4990729',
#     'name': 'Detroit',
#     'state': 'Michigan',
#     'stateCode': 'MI',
#     'coords': {'lat': 42.331427, 'long': -83.0457538},
#     'country': {'code': 'US', 'name': 'United States'}},
#    'url': 'https://www.setlist.fm/venue/olympia-stadium-detroit-mi-usa-63d62657.html'},
#   'tour': {'name': 'North American Tour 1966'},
#   'sets': {'set': [{'song': [{'name': 'Rock and Roll Music',
#        'cover': {'mbid': '592a3b6d-c42b-4567-99c9-ecf63bd66499',
#         'name': 'Chuck Berry',
#         'sortName': 'Berry, Chuck',
#         'disambiguation': '',
#         'url': 'https://www.setlist.fm/setlists/chuck-berry-63d6a2b7.html'}},
#       {'name': "She's a Woman"},
#       {'name': 'If I Needed Someone'},
#       {'name': 'Day Tripper'},
#       {'name': "Baby's in Black"},
#       {'name': 'I Feel Fine'},
#       {'name': 'Yesterday'},
#       {'name': 'I Wanna Be Your Man'},
#       {'name': 'Nowhere Man'},
#       {'name': 'Paperback Writer'},
#       {'name': "I'm Down"}]}]},
#   'info': '2:00PM Show',
#   'url': 'https://www.setlist.fm/setlist/the-beatles/1966/olympia-stadium-detroit-mi-3bcc4070.html'}]

# %%
# test = pd.DataFrame(response.json()['businesses'])
test = pd.DataFrame(b.json()['setlist'])
test.head()
# Out:
#          id  versionId   eventDate                   lastUpdated  \
# 0  53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# 1  73c18a19   13367d11  04-09-1968  2020-01-17T01:22:37.000+0000
# 2  43c26b8b  g2bc1485a  25-06-1967  2022-02-24T08:01:13.000+0000
# 3   bf88dc2   1b3bcd80  24-06-1967  2020-06-02T08:45:06.000+0000
# 4  73d67e09   7b069680  29-08-1966  2019-07-10T19:44:01.000+0000
#
#                                               artist  \
# 0  {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d...
# 1  {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d...
# 2  {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d...
# 3  {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d...
# 4  {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d...
#
#                                                venue  \
# 0  {'id': '4bd627fe', 'name': 'Apple Corps Roofto...
# 1  {'id': '4bd5973e', 'name': 'Twickenham Studios...
# 2  {'id': '43d207b3', 'name': 'EMI Recording Stud...
# 3  {'id': '43d207b3', 'name': 'EMI Recording Stud...
# 4  {'id': '3bd624d4', 'name': 'Candlestick Park',...
#
#                                                 sets  \
# 0  {'set': [{'song': [{'name': 'Get Back'}, {'nam...
# 1  {'set': [{'name': '"Hey Jude" film sessions', ...
# 2  {'set': [{'song': [{'name': 'All You Need Is L...
# 3  {'set': [{'song': [{'name': 'All You Need Is L...
# 4  {'set': [{'song': [{'name': 'Rock and Roll Mus...
#
#                                                 info  \
# 0  The Beatles' last public performance. Band pla...
# 1                    Broadcast on September 8th 1968
# 2  Representing the UK on 'Our World’ the first l...
# 3                 Open-door rehearsal for the press.
# 4                 Last public performance until 1969
#
#                                                  url  \
# 0  https://www.setlist.fm/setlist/the-beatles/196...
# 1  https://www.setlist.fm/setlist/the-beatles/196...
# 2  https://www.setlist.fm/setlist/the-beatles/196...
# 3  https://www.setlist.fm/setlist/the-beatles/196...
# 4  https://www.setlist.fm/setlist/the-beatles/196...
#
#                                    tour
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4  {'name': 'North American Tour 1966'}

# %%
# yelp_info_df = yelp_info['location'].apply(pd.Series)
test_df = test['sets'].apply(pd.Series)
test_df.head()
# Out:
#                                                  set
# 0  [{'song': [{'name': 'Get Back'}, {'name': 'Get...
# 1  [{'name': '"Hey Jude" film sessions', 'song': ...
# 2     [{'song': [{'name': 'All You Need Is Love'}]}]
# 3  [{'song': [{'name': 'All You Need Is Love', 'i...
# 4  [{'song': [{'name': 'Rock and Roll Music', 'co...

# %%
# yelp_info_df1 = yelp_info_df[['address1','city','zip_code','state']]

test_df = test_df[['set']]
test_df.head()
# Out:
#                                                  set
# 0  [{'song': [{'name': 'Get Back'}, {'name': 'Get...
# 1  [{'name': '"Hey Jude" film sessions', 'song': ...
# 2     [{'song': [{'name': 'All You Need Is Love'}]}]
# 3  [{'song': [{'name': 'All You Need Is Love', 'i...
# 4  [{'song': [{'name': 'Rock and Roll Music', 'co...

# %%
b_test = b.json()
ids = []
versionid = []
eventdate = []
lastupdated = []
artist = []
venue = []
song = []
for x in b_test['setlist']:
    for y in x['sets']['set'][0]['song']:
        song.append(y['name'])
        ids.append(x['id'])
        versionid.append(x['versionId'])
        eventdate.append(x['eventDate'])
        lastupdated.append(x['lastUpdated'])
        artist.append(x['artist']['name'])
        venue.append(x['venue']['name'])
b_setlist_test = pd.DataFrame({'id': ids, 'versionid': versionid, 'eventdate': eventdate, 'lastupdated': lastupdated, 'artist': artist, 'venue': venue, 'song': song})
b_setlist_test
# Out:
#            id  versionid   eventdate                   lastupdated  \
# 0    53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# 1    53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# 2    53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# 3    53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# 4    53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# ..        ...        ...         ...                           ...
# 191  3bcc4070   33873cc1  13-08-1966  2014-11-16T05:46:23.000+0000
# 192  3bcc4070   33873cc1  13-08-1966  2014-11-16T05:46:23.000+0000
# 193  3bcc4070   33873cc1  13-08-1966  2014-11-16T05:46:23.000+0000
# 194  3bcc4070   33873cc1  13-08-1966  2014-11-16T05:46:23.000+0000
# 195  3bcc4070   33873cc1  13-08-1966  2014-11-16T05:46:23.000+0000
#
#           artist                venue                 song
# 0    The Beatles  Apple Corps Rooftop             Get Back
# 1    The Beatles  Apple Corps Rooftop             Get Back
# 2    The Beatles  Apple Corps Rooftop    Don't Let Me Down
# 3    The Beatles  Apple Corps Rooftop   I've Got a Feeling
# 4    The Beatles  Apple Corps Rooftop        One After 909
# ..           ...                  ...                  ...
# 191  The Beatles      Olympia Stadium            Yesterday
# 192  The Beatles      Olympia Stadium  I Wanna Be Your Man
# 193  The Beatles      Olympia Stadium          Nowhere Man
# 194  The Beatles      Olympia Stadium     Paperback Writer
# 195  The Beatles      Olympia Stadium             I'm Down
#
# [196 rows x 7 columns]

# %%
b_test = b.json()
ids = []
versionid = []
eventdate = []
lastupdated = []
artist = []
venue = []
song = []
for x in b_test['artist']:
    for y in x['sets']['set'][0]['song']:
        song.append(y['name'])
        ids.append(x['id'])
        versionid.append(x['versionId'])
        eventdate.append(x['eventDate'])
        lastupdated.append(x['lastUpdated'])
        artist.append(x['artist']['name'])
        venue.append(x['venue']['name'])
b_setlist_test = pd.DataFrame({'id': ids, 'versionid': versionid, 'eventdate': eventdate, 'lastupdated': lastupdated, 'artist': artist, 'venue': venue, 'song': song})
b_setlist_test
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [9], in <cell line: 9>()
#       7 venue = []
#       8 song = []
# ----> 9 for x in b_test['artist']:
#      10     for y in x['sets']['set'][0]['song']:
#      11         song.append(y['name'])
#
# KeyError: 'artist'

# %%
b_setlist_test.head()
# Out:
#          id  versionid   eventdate                   lastupdated       artist  \
# 0  53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000  The Beatles
# 1  53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000  The Beatles
# 2  53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000  The Beatles
# 3  53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000  The Beatles
# 4  53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000  The Beatles
#
#                  venue                song
# 0  Apple Corps Rooftop            Get Back
# 1  Apple Corps Rooftop            Get Back
# 2  Apple Corps Rooftop   Don't Let Me Down
# 3  Apple Corps Rooftop  I've Got a Feeling
# 4  Apple Corps Rooftop       One After 909

# %%
artist_df = test['artist'].apply(pd.Series)
artist_df.head()
# Out:
#                                    mbid         name      sortName  \
# 0  b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d  The Beatles  Beatles, The
# 1  b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d  The Beatles  Beatles, The
# 2  b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d  The Beatles  Beatles, The
# 3  b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d  The Beatles  Beatles, The
# 4  b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d  The Beatles  Beatles, The
#
#   disambiguation                                                url
# 0                 https://www.setlist.fm/setlists/the-beatles-23...
# 1                 https://www.setlist.fm/setlists/the-beatles-23...
# 2                 https://www.setlist.fm/setlists/the-beatles-23...
# 3                 https://www.setlist.fm/setlists/the-beatles-23...
# 4                 https://www.setlist.fm/setlists/the-beatles-23...

# %%
test.head()

# %%
header={
    "Accept":"application/json", 
    "x-api-key":api_key
}


c=requests.get("https://api.setlist.fm/rest/1.0/artist/9725f5a1-3d65-488a-8a82-54c1483beb7c/setlists?p=1", headers=header)
print(c)

# %%
c_test = c.json()
ids = []
versionid = []
eventdate = []
lastupdated = []
artist = []
venue = []
song = []
for x in c_test['setlist']:
    for y in x['sets']['set'][0]['song']:
        song.append(y['name'])
        ids.append(x['id'])
        versionid.append(x['versionId'])
        eventdate.append(x['eventDate'])
        lastupdated.append(x['lastUpdated'])
        artist.append(x['artist']['name'])
        venue.append(x['venue']['name'])
c_setlist_test = pd.DataFrame({'id': ids, 'versionid': versionid, 'eventdate': eventdate, 'lastupdated': lastupdated, 'artist': artist, 'venue': venue, 'song': song})
c_setlist_test

# %%
header={
    "Accept":"application/json", 
    "x-api-key":api_key
}


g=requests.get("https://api.setlist.fm/rest/1.0/search/setlists?countryCode=US&p=1", headers=header)
print(g)
# Out:
# <Response [200]>

# %%
g.json()
# Out:
# {'type': 'setlists',
#  'itemsPerPage': 20,
#  'page': 1,
#  'total': 2808092,
#  'setlist': [{'id': '6bbf567e',
#    'versionId': 'g3e2e1d7',
#    'eventDate': '09-12-2022',
#    'lastUpdated': '2022-12-07T01:21:44.000+0000',
#    'artist': {'mbid': '128e1f3c-a110-4320-8202-4ad997f0a6d0',
#     'name': 'Michael Mayo',
#     'sortName': 'Mayo, Michael',
#     'disambiguation': 'Classic Vocal Style',
#     'url': 'https://www.setlist.fm/setlists/michael-mayo-33c9c445.html'},
#    'venue': {'id': '3d4d113',
#     'name': 'The Ardmore Music Hall',
#     'city': {'id': '5178481',
#      'name': 'Ardmore',
#      'state': 'Pennsylvania',
#      'stateCode': 'PA',
#      'coords': {'lat': 40.0067786, 'long': -75.2854622},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/the-ardmore-music-hall-ardmore-pa-usa-3d4d113.html'},
#    'sets': {'set': []},
#    'url': 'https://www.setlist.fm/setlist/michael-mayo/2022/the-ardmore-music-hall-ardmore-pa-6bbf567e.html'},
#   {'id': '7bbf5678',
#    'versionId': 'gbe2e1d2',
#    'eventDate': '09-12-2022',
#    'lastUpdated': '2022-12-07T01:21:20.000+0000',
#    'artist': {'mbid': '0d5a2ace-da04-4b56-89bb-feb5fb6bc184',
#     'name': 'Nate Smith',
#     'sortName': 'Smith, Nate',
#     'disambiguation': 'jazz drummer',
#     'url': 'https://www.setlist.fm/setlists/nate-smith-bd4cd2a.html'},
#    'venue': {'id': '3d4d113',
#     'name': 'The Ardmore Music Hall',
#     'city': {'id': '5178481',
#      'name': 'Ardmore',
#      'state': 'Pennsylvania',
#      'stateCode': 'PA',
#      'coords': {'lat': 40.0067786, 'long': -75.2854622},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/the-ardmore-music-hall-ardmore-pa-usa-3d4d113.html'},
#    'sets': {'set': []},
#    'url': 'https://www.setlist.fm/setlist/nate-smith/2022/the-ardmore-music-hall-ardmore-pa-7bbf5678.html'},
#   {'id': '43bf5783',
#    'versionId': 'g13e2e1ed',
#    'eventDate': '09-12-2022',
#    'lastUpdated': '2022-12-07T01:18:54.000+0000',
#    'artist': {'mbid': '5a7a6405-c36e-4c4a-9fa8-87c54288d1f2',
#     'name': 'The Hugs',
#     'sortName': 'Hugs, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-hugs-53f22715.html'},
#    'venue': {'id': '4bd6133a',
#     'name': "Sam Bond's Garage",
#     'city': {'id': '5725846',
#      'name': 'Eugene',
#      'state': 'Oregon',
#      'stateCode': 'OR',
#      'coords': {'lat': 44.0520691, 'long': -123.0867536},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/sam-bonds-garage-eugene-or-usa-4bd6133a.html'},
#    'sets': {'set': []},
#    'url': 'https://www.setlist.fm/setlist/the-hugs/2022/sam-bonds-garage-eugene-or-43bf5783.html'},
#   {'id': '5bbf578c',
#    'versionId': 'g3e2e1ef',
#    'eventDate': '09-12-2022',
#    'lastUpdated': '2022-12-07T01:18:36.000+0000',
#    'artist': {'mbid': '8bf22328-30d7-4075-8a8d-b395dbed1bc7',
#     'name': 'Tolliver',
#     'sortName': 'Tolliver',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/tolliver-4bfd4b7a.html'},
#    'venue': {'id': '4bd33b66',
#     'name': 'Soreng Theater',
#     'city': {'id': '5725846',
#      'name': 'Eugene',
#      'state': 'Oregon',
#      'stateCode': 'OR',
#      'coords': {'lat': 44.0520691, 'long': -123.0867536},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/soreng-theater-eugene-or-usa-4bd33b66.html'},
#    'sets': {'set': []},
#    'url': 'https://www.setlist.fm/setlist/tolliver/2022/soreng-theater-eugene-or-5bbf578c.html'},
#   {'id': '43bf578f',
#    'versionId': 'g1be2e1f4',
#    'eventDate': '09-12-2022',
#    'lastUpdated': '2022-12-07T01:17:36.000+0000',
#    'artist': {'mbid': '4013e360-5307-4c18-b7cb-fb569e15a87b',
#     'name': 'Tony Coleman',
#     'sortName': 'Coleman, Tony',
#     'disambiguation': 'blues singer, member of The Knight Crew',
#     'url': 'https://www.setlist.fm/setlists/tony-coleman-2bc6e09a.html'},
#    'venue': {'id': 'bd2056a',
#     'name': 'The Jack London Revue',
#     'city': {'id': '5746545',
#      'name': 'Portland',
#      'state': 'Oregon',
#      'stateCode': 'OR',
#      'coords': {'lat': 45.5234515, 'long': -122.6762071},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/the-jack-london-revue-portland-or-usa-bd2056a.html'},
#    'sets': {'set': []},
#    'url': 'https://www.setlist.fm/setlist/tony-coleman/2022/the-jack-london-revue-portland-or-43bf578f.html'},
#   {'id': '53bf5789',
#    'versionId': 'gbe2e1f6',
#    'eventDate': '09-12-2022',
#    'lastUpdated': '2022-12-07T01:17:17.000+0000',
#    'artist': {'mbid': 'b0a3dda1-2cc0-404e-a26d-cdb3f302eb41',
#     'name': 'Al Franken',
#     'sortName': 'Franken, Al',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/al-franken-1bc6f9d4.html'},
#    'venue': {'id': '3bd62c64',
#     'name': 'Crest Theatre',
#     'city': {'id': '5389489',
#      'name': 'Sacramento',
#      'state': 'California',
#      'stateCode': 'CA',
#      'coords': {'lat': 38.5815719, 'long': -121.4943996},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/crest-theatre-sacramento-ca-usa-3bd62c64.html'},
#    'tour': {'name': 'The Only Former U.S. Senator Currently On Tour'},
#    'sets': {'set': []},
#    'url': 'https://www.setlist.fm/setlist/al-franken/2022/crest-theatre-sacramento-ca-53bf5789.html'},
#   {'id': '53bf5795',
#    'versionId': 'g3e2e1ff',
#    'eventDate': '09-12-2022',
#    'lastUpdated': '2022-12-07T01:15:48.000+0000',
#    'artist': {'mbid': 'a9e5337b-0608-4401-91d4-18ab4cf47ff8',
#     'name': 'Peter Mulvey',
#     'sortName': 'Mulvey, Peter',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/peter-mulvey-73d626cd.html'},
#    'venue': {'id': '7bd7d21c',
#     'name': 'Cafe Carpe',
#     'city': {'id': '5253498',
#      'name': 'Fort Atkinson',
#      'state': 'Wisconsin',
#      'stateCode': 'WI',
#      'coords': {'lat': 42.9288944, 'long': -88.8370509},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/cafe-carpe-fort-atkinson-wi-usa-7bd7d21c.html'},
#    'tour': {'name': 'Lamplighter Sessions 2022'},
#    'sets': {'set': []},
#    'url': 'https://www.setlist.fm/setlist/peter-mulvey/2022/cafe-carpe-fort-atkinson-wi-53bf5795.html'},
#   {'id': '5bbf57ac',
#    'versionId': 'g3e2e127',
#    'eventDate': '09-12-2022',
#    'lastUpdated': '2022-12-07T01:09:06.000+0000',
#    'artist': {'mbid': 'b569861e-935b-434e-b521-7f77991299aa',
#     'name': 'Bonny Light Horseman',
#     'sortName': 'Bonny Light Horseman',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/bonny-light-horseman-4bf657e6.html'},
#    'venue': {'id': '33d798b1',
#     'name': 'Motorco Music Hall',
#     'city': {'id': '4464368',
#      'name': 'Durham',
#      'state': 'North Carolina',
#      'stateCode': 'NC',
#      'coords': {'lat': 35.9940329, 'long': -78.898619},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/motorco-music-hall-durham-nc-usa-33d798b1.html'},
#    'tour': {'name': 'Rolling Golden Holy'},
#    'sets': {'set': []},
#    'url': 'https://www.setlist.fm/setlist/bonny-light-horseman/2022/motorco-music-hall-durham-nc-5bbf57ac.html'},
#   {'id': '4bbf57aa',
#    'versionId': 'g1be2e128',
#    'eventDate': '09-12-2022',
#    'lastUpdated': '2022-12-07T01:08:21.000+0000',
#    'artist': {'mbid': '4fdcc64a-4686-4b16-a384-7ef1e51954d3',
#     'name': 'Alton Brown',
#     'sortName': 'Brown, Alton',
#     'disambiguation': 'American chef, author and musician',
#     'url': 'https://www.setlist.fm/setlists/alton-brown-33f554cd.html'},
#    'venue': {'id': '7bd3d6b0',
#     'name': 'ArcBest Corporation Performing Arts Center',
#     'city': {'id': '4111410',
#      'name': 'Fort Smith',
#      'state': 'Arkansas',
#      'stateCode': 'AR',
#      'coords': {'lat': 35.3859242, 'long': -94.3985475},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/arcbest-corporation-performing-arts-center-fort-smith-ar-usa-7bd3d6b0.html'},
#    'tour': {'name': 'Beyond the Eats: The Holiday Variant!'},
#    'sets': {'set': []},
#    'url': 'https://www.setlist.fm/setlist/alton-brown/2022/arcbest-corporation-performing-arts-center-fort-smith-ar-4bbf57aa.html'},
#   {'id': '5bbf57b4',
#    'versionId': 'g3e2e12b',
#    'eventDate': '09-12-2022',
#    'lastUpdated': '2022-12-07T01:08:09.000+0000',
#    'artist': {'mbid': '9c7ba2ec-8039-41f0-a2f9-5449f8af6a9c',
#     'name': 'Starz',
#     'sortName': 'Starz',
#     'disambiguation': '70s New Jersey hard rock/power pop band',
#     'url': 'https://www.setlist.fm/setlists/starz-53d7a751.html'},
#    'venue': {'id': '1bd631a0',
#     'name': 'Dingbatz',
#     'city': {'id': '5096699',
#      'name': 'Clifton',
#      'state': 'New Jersey',
#      'stateCode': 'NJ',
#      'coords': {'lat': 40.8584328, 'long': -74.1637553},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/dingbatz-clifton-nj-usa-1bd631a0.html'},
#    'sets': {'set': []},
#    'url': 'https://www.setlist.fm/setlist/starz/2022/dingbatz-clifton-nj-5bbf57b4.html'},
#   {'id': '53bf57b5',
#    'versionId': 'g13e2e135',
#    'eventDate': '09-12-2022',
#    'lastUpdated': '2022-12-07T01:07:53.000+0000',
#    'artist': {'mbid': '15f835dc-ee52-4b74-b889-113678f54119',
#     'name': 'My Brightest Diamond',
#     'sortName': 'My Brightest Diamond',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/my-brightest-diamond-3bd6e87c.html'},
#    'venue': {'id': '3d60113',
#     'name': 'Fourth Presbyterian Church',
#     'city': {'id': '4887398',
#      'name': 'Chicago',
#      'state': 'Illinois',
#      'stateCode': 'IL',
#      'coords': {'lat': 41.850033, 'long': -87.6500523},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/fourth-presbyterian-church-chicago-il-usa-3d60113.html'},
#    'sets': {'set': []},
#    'info': 'Opening for Andrew Bird.',
#    'url': 'https://www.setlist.fm/setlist/my-brightest-diamond/2022/fourth-presbyterian-church-chicago-il-53bf57b5.html'},
#   {'id': '4bbf57b6',
#    'versionId': 'g3e2e137',
#    'eventDate': '09-12-2022',
#    'lastUpdated': '2022-12-07T01:07:17.000+0000',
#    'artist': {'mbid': '1d908ca0-f461-4046-b39a-05c27b7e7964',
#     'name': 'Charlie Hunter & Scott Amendola',
#     'sortName': 'Charlie Hunter & Scott Amendola',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/charlie-hunter-and-scott-amendola-3bf4f4f8.html'},
#    'venue': {'id': '23d2cc5f',
#     'name': 'Ivy Room',
#     'city': {'id': '5322850',
#      'name': 'Albany',
#      'state': 'California',
#      'stateCode': 'CA',
#      'coords': {'lat': 37.88687, 'long': -122.2977475},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/ivy-room-albany-ca-usa-23d2cc5f.html'},
#    'sets': {'set': []},
#    'url': 'https://www.setlist.fm/setlist/charlie-hunter-and-scott-amendola/2022/ivy-room-albany-ca-4bbf57b6.html'},
#   {'id': '4bbf57c2',
#    'versionId': 'g13e2e155',
#    'eventDate': '09-12-2022',
#    'lastUpdated': '2022-12-07T01:04:07.000+0000',
#    'artist': {'mbid': 'af953ba2-283b-41ef-93bc-b4cfc5feeebc',
#     'name': 'Darlene Love',
#     'sortName': 'Love, Darlene',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/darlene-love-bd69d4e.html'},
#    'venue': {'id': '63d6d6eb',
#     'name': 'Bergen Performing Arts Center',
#     'city': {'id': '5097672',
#      'name': 'Englewood',
#      'state': 'New Jersey',
#      'stateCode': 'NJ',
#      'coords': {'lat': 40.8928771, 'long': -73.9726381},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/bergen-performing-arts-center-englewood-nj-usa-63d6d6eb.html'},
#    'tour': {'name': 'Love for the Holidays 2022'},
#    'sets': {'set': []},
#    'url': 'https://www.setlist.fm/setlist/darlene-love/2022/bergen-performing-arts-center-englewood-nj-4bbf57c2.html'},
#   {'id': '3bbf5484',
#    'versionId': 'g13e2e171',
#    'eventDate': '09-12-2022',
#    'lastUpdated': '2022-12-07T00:59:51.000+0000',
#    'artist': {'mbid': 'c116b504-ce24-4264-96dc-d10a7458236f',
#     'name': 'Julian Lage',
#     'sortName': 'Lage, Julian',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/julian-lage-bd03d5a.html'},
#    'venue': {'id': '13d615b1',
#     'name': 'The Grey Eagle',
#     'city': {'id': '4453066',
#      'name': 'Asheville',
#      'state': 'North Carolina',
#      'stateCode': 'NC',
#      'coords': {'lat': 35.6009452, 'long': -82.554015},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/the-grey-eagle-asheville-nc-usa-13d615b1.html'},
#    'tour': {'name': 'View With a Room'},
#    'sets': {'set': []},
#    'url': 'https://www.setlist.fm/setlist/julian-lage/2022/the-grey-eagle-asheville-nc-3bbf5484.html'},
#   {'id': '5bbf5718',
#    'versionId': 'g7be2e684',
#    'eventDate': '09-12-2022',
#    'lastUpdated': '2022-12-07T00:54:25.000+0000',
#    'artist': {'mbid': '0939452b-0c6f-422a-997f-e7c496ce1113',
#     'name': 'Chris Botti',
#     'sortName': 'Botti, Chris',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/chris-botti-2bd660e6.html'},
#    'venue': {'id': '23d4b48f',
#     'name': 'Blue Note Jazz Club',
#     'city': {'id': '5128581',
#      'name': 'New York',
#      'state': 'New York',
#      'stateCode': 'NY',
#      'coords': {'lat': 40.7142691, 'long': -74.0059729},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/blue-note-jazz-club-new-york-ny-usa-23d4b48f.html'},
#    'tour': {'name': '18th Annual Holiday Residency'},
#    'sets': {'set': []},
#    'info': 'Late show',
#    'url': 'https://www.setlist.fm/setlist/chris-botti/2022/blue-note-jazz-club-new-york-ny-5bbf5718.html'},
#   {'id': '4bbf57e2',
#    'versionId': 'g73e2e681',
#    'eventDate': '09-12-2022',
#    'lastUpdated': '2022-12-07T00:53:42.000+0000',
#    'artist': {'mbid': '0939452b-0c6f-422a-997f-e7c496ce1113',
#     'name': 'Chris Botti',
#     'sortName': 'Botti, Chris',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/chris-botti-2bd660e6.html'},
#    'venue': {'id': '23d4b48f',
#     'name': 'Blue Note Jazz Club',
#     'city': {'id': '5128581',
#      'name': 'New York',
#      'state': 'New York',
#      'stateCode': 'NY',
#      'coords': {'lat': 40.7142691, 'long': -74.0059729},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/blue-note-jazz-club-new-york-ny-usa-23d4b48f.html'},
#    'tour': {'name': '18th Annual Holiday Residency'},
#    'sets': {'set': []},
#    'info': 'Early show',
#    'url': 'https://www.setlist.fm/setlist/chris-botti/2022/blue-note-jazz-club-new-york-ny-4bbf57e2.html'},
#   {'id': '43bf57e7',
#    'versionId': 'g73e2e69d',
#    'eventDate': '09-12-2022',
#    'lastUpdated': '2022-12-07T00:49:17.000+0000',
#    'artist': {'mbid': 'b5415c6f-a2c3-48b4-a2a4-e9efbb577d10',
#     'name': 'Australian Bee Gees',
#     'sortName': 'Australian Bee Gees',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/australian-bee-gees-2bce68ce.html'},
#    'venue': {'id': '3bd4b000',
#     'name': 'Excalibur Hotel & Casino',
#     'city': {'id': '5506956',
#      'name': 'Las Vegas',
#      'state': 'Nevada',
#      'stateCode': 'NV',
#      'coords': {'lat': 36.1749705, 'long': -115.137223},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/excalibur-hotel-and-casino-las-vegas-nv-usa-3bd4b000.html'},
#    'sets': {'set': []},
#    'url': 'https://www.setlist.fm/setlist/australian-bee-gees/2022/excalibur-hotel-and-casino-las-vegas-nv-43bf57e7.html'},
#   {'id': '5bbf57e0',
#    'versionId': 'g6be2e69e',
#    'eventDate': '09-12-2022',
#    'lastUpdated': '2022-12-07T00:48:31.000+0000',
#    'artist': {'mbid': '7bb60591-46f3-4147-b692-1814a87e832e',
#     'name': 'Barry Manilow',
#     'sortName': 'Manilow, Barry',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/barry-manilow-63d6be13.html'},
#    'venue': {'id': '3bd46894',
#     'name': 'Westgate Las Vegas Resort & Casino',
#     'city': {'id': '5506956',
#      'name': 'Las Vegas',
#      'state': 'Nevada',
#      'stateCode': 'NV',
#      'coords': {'lat': 36.1749705, 'long': -115.137223},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/westgate-las-vegas-resort-and-casino-las-vegas-nv-usa-3bd46894.html'},
#    'tour': {'name': 'A Very Barry Christmas 2022'},
#    'sets': {'set': []},
#    'url': 'https://www.setlist.fm/setlist/barry-manilow/2022/westgate-las-vegas-resort-and-casino-las-vegas-nv-5bbf57e0.html'},
#   {'id': '53bf57e1',
#    'versionId': 'g73e2e6a5',
#    'eventDate': '09-12-2022',
#    'lastUpdated': '2022-12-07T00:47:05.000+0000',
#    'artist': {'mbid': 'aab35942-f176-4f77-bbf9-1d6aa98ccf3f',
#     'name': 'Luke Bryan',
#     'sortName': 'Bryan, Luke',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/luke-bryan-7bd72224.html'},
#    'venue': {'id': '6bd0da76',
#     'name': 'Resorts World Theatre',
#     'city': {'id': '5506956',
#      'name': 'Las Vegas',
#      'state': 'Nevada',
#      'stateCode': 'NV',
#      'coords': {'lat': 36.1749705, 'long': -115.137223},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/resorts-world-theatre-las-vegas-nv-usa-6bd0da76.html'},
#    'sets': {'set': []},
#    'url': 'https://www.setlist.fm/setlist/luke-bryan/2022/resorts-world-theatre-las-vegas-nv-53bf57e1.html'},
#   {'id': '43bf57e3',
#    'versionId': 'g7be2e6a0',
#    'eventDate': '09-12-2022',
#    'lastUpdated': '2022-12-07T00:46:30.000+0000',
#    'artist': {'mbid': '28fd67e8-573c-4cdd-a37d-8b74af74109c',
#     'name': 'The Queers',
#     'sortName': 'Queers, The',
#     'disambiguation': '',
#     'url': 'https://www.setlist.fm/setlists/the-queers-6bd6ea1e.html'},
#    'venue': {'id': 'bd3bde6',
#     'name': 'Melody Inn',
#     'city': {'id': '4259418',
#      'name': 'Indianapolis',
#      'state': 'Indiana',
#      'stateCode': 'IN',
#      'coords': {'lat': 39.7683765, 'long': -86.1580423},
#      'country': {'code': 'US', 'name': 'United States'}},
#     'url': 'https://www.setlist.fm/venue/melody-inn-indianapolis-in-usa-bd3bde6.html'},
#    'tour': {'name': '40 Years of the Queers'},
#    'sets': {'set': []},
#    'url': 'https://www.setlist.fm/setlist/the-queers/2022/melody-inn-indianapolis-in-43bf57e3.html'}]}

# %%
# test = pd.DataFrame(b.json()['setlist'])
test = pd.DataFrame(g.json()['setlist']
# Out:
#   Input In [13]
#     test = pd.DataFrame(g.json()['setlist']
#                                            ^
# SyntaxError: unexpected EOF while parsing
