# %%
import requests
import json
import numpy as np
import pandas as pd
import time

with open('../Data/api_key.json') as fi:
    credentials = json.load(fi)
    
api_key = credentials['api_key']

# %%
header={
    "Accept":"application/json", 
    "x-api-key":api_key
}


b=requests.get("https://api.setlist.fm/rest/1.0/artist/b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d/setlists?p=1", headers=header)
print(b)
# Out:
# <Response [200]>

# %%
b_test = b.json()
ids = []
versionid = []
eventdate = []
lastupdated = []
artist = []
venue = []
song = []
for x in b_test['setlist']:
    for y in x['sets']['set'][0]['song']:
        song.append(y['name'])
        ids.append(x['id'])
        versionid.append(x['versionId'])
        eventdate.append(x['eventDate'])
        lastupdated.append(x['lastUpdated'])
        artist.append(x['artist']['name'])
        venue.append(x['venue']['name'])
b_setlist_test = pd.DataFrame({'id': ids, 'versionid': versionid, 'eventdate': eventdate, 'lastupdated': lastupdated, 'artist': artist, 'venue': venue, 'song': song})
b_setlist_test
# Out:
#            id  versionid   eventdate                   lastupdated  \
# 0    53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# 1    53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# 2    53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# 3    53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# 4    53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# ..        ...        ...         ...                           ...
# 191  3bcc4070   33873cc1  13-08-1966  2014-11-16T05:46:23.000+0000
# 192  3bcc4070   33873cc1  13-08-1966  2014-11-16T05:46:23.000+0000
# 193  3bcc4070   33873cc1  13-08-1966  2014-11-16T05:46:23.000+0000
# 194  3bcc4070   33873cc1  13-08-1966  2014-11-16T05:46:23.000+0000
# 195  3bcc4070   33873cc1  13-08-1966  2014-11-16T05:46:23.000+0000
#
#           artist                venue                 song
# 0    The Beatles  Apple Corps Rooftop             Get Back
# ...

# %% [markdown]
# tried on another request and added a column, MBID (artist unique identifier) in order to pull set lists of the artists.

# %%
header={
    "Accept":"application/json", 
    "x-api-key":api_key
}


g=requests.get("https://api.setlist.fm/rest/1.0/search/setlists?countryCode=US&p=1", headers=header)
print(g)
# Out:
# <Response [200]>

# %%
g_test = g.json()
ids = []
versionid = []
eventdate = []
lastupdated = []
artist = []
mbid = []
venue = []
song = []
for x in g_test['setlist']:
        song.append(y['name'])
        ids.append(x['id'])
        versionid.append(x['versionId'])
        eventdate.append(x['eventDate'])
        lastupdated.append(x['lastUpdated'])
        artist.append(x['artist']['name'])
        mbid.append(x['artist']['mbid'])
        venue.append(x['venue']['name'])
g_df_test = pd.DataFrame({'id': ids, 'versionid': versionid, 'eventdate': eventdate, 'lastupdated': lastupdated, 'artist': artist,'mbid':mbid, 'venue': venue, 'song': song})
g_df_test
# Out:
#           id  versionid   eventdate                   lastupdated  \
# 0   73bf56b9  g53e2e361  09-12-2022  2022-12-07T03:00:40.000+0000
# 1   73bf56d1  g3be2e090  09-12-2022  2022-12-07T02:46:00.000+0000
# 2   63bf56df  g23e2e09f  09-12-2022  2022-12-07T02:43:34.000+0000
# 3   73bf56e1  g2be2e0a2  09-12-2022  2022-12-07T02:42:34.000+0000
# 4   7bbf5634  g23e2e013  09-12-2022  2022-12-07T02:19:38.000+0000
# 5   7bbf5630  g3be2e018  09-12-2022  2022-12-07T02:18:32.000+0000
# 6   43bf5727  g2be2e046  09-12-2022  2022-12-07T02:08:00.000+0000
# 7   6bbf567e   g3e2e1d7  09-12-2022  2022-12-07T01:21:44.000+0000
# 8   7bbf5678   gbe2e1d2  09-12-2022  2022-12-07T01:21:20.000+0000
# 9   43bf5783  g13e2e1ed  09-12-2022  2022-12-07T01:18:54.000+0000
# 10  5bbf578c   g3e2e1ef  09-12-2022  2022-12-07T01:18:36.000+0000
# 11  43bf578f  g1be2e1f4  09-12-2022  2022-12-07T01:17:36.000+0000
# 12  53bf5789   gbe2e1f6  09-12-2022  2022-12-07T01:17:17.000+0000
# ...

# %%
header={
    "Accept":"application/json", 
    "x-api-key":api_key
}


nash_venues=requests.get("https://api.setlist.fm/rest/1.0/search/venues?cityName=Nashville&p=1&stateCode=TN", headers=header)
print(nash_venues)
# Out:
# <Response [200]>

# %%
# Out:
#           id          name
# 0   63d20e47     Nashville
# 1   6bd5de4a     Nashville
# 2   33d4bccd     Nashville
# 3   6bd44ade     Nashville
# 4   73d0ee21     Nashville
# 5   1bd4fd34     Nashville
# 6   33d0e041     Nashville
# 7   1bd08d84     Nashville
# 8   1bd075c4  Murfreesboro
# 9   53d04b7d     Nashville
# 10  2bd0bcf2     Nashville
# 11  6bd2aa3e  Murfreesboro
# 12  13d32db9     Nashville
# 13  2bd29ce2     Nashville
# 14   3d5cdc7     Nashville
# 15  3bd49c4c     Nashville
# 16  63d03ed3   Clarksville
# 17  3bd71c74     Nashville
# 18  13d521dd       Lebanon
# 19  13d0c149      Franklin
# 20   3d099d7     Nashville
# 21  1bd619e8     Nashville
# 22  6bd3d6ba     Nashville
# 23  53d55f11   Clarksville
# 24  1bd20170      Franklin
# 25  13d0592d     Nashville
# 26  43d20b0f     Nashville
# 27  4bd03346      Franklin
# 28  4bd01f16   Clarksville
# 29  13d3f951     Nashville

# %%
# mbid.append(x['artist']['mbid'])

nash_venues_test['venue'][0]['city']['name']

# city_name.append(x['city']['name'])
# Out:
# 'Nashville'
