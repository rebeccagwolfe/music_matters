# %%
import requests
import json
import numpy as np
import pandas as pd
import time

with open('api_key.json') as fi:
    credentials = json.load(fi)
    
api_key = credentials['api_key']

# %% [markdown]
# # EDA Notebook to look at data in every API response option:
#
#
# - /1.0/artist/{mbid} - (a)
#
# - /1.0/artist/{mbid}/setlists - (b)
#
#
# - /1.0/city/{geoId} - (c)
#
# - /1.0/search/artists - (d)
#
# - /1.0/search/cities - (e)
#
# - /1.0/search/countries - (f)
#
# - /1.0/search/setlists - (g)
#
# - /1.0/search/venues - (h)
#
# - /1.0/setlist/{setlistId} (i)
#
# - /1.0/setlist/version/{versionId} - (j)
#
# - /1.0/setlist/{setlistId} - (k)
#
# - /1.0/user/{userId} - (l)
#
# - /1.0/user/{userId}/attended - (m)
#
# - /1.0/user/{userId}/edited - (n)
#
# - /1.0/venue/{venueId} - (o)
#
# - /1.0/venue/{venueId}/setlists - (p)

# %% [markdown]
# # a
#
# ## /1.0/artist/{mbid

# %%
header={
    "Accept":"application/json", 
    "x-api-key":api_key
}


a_df=requests.get("https://api.setlist.fm/rest/1.0/artist/0bfba3d3-6a04-4779-bb0a-df07df5b0558", headers=header)
print(a_df)
# Out:
# <Response [200]>

# %%
# didn't work
# a_df=pd.DataFrame(a_df.json())
# a_df.head()

# %% [markdown]
# # b
#
# ### /1.0/artist/{mbid}/setlists

# %%
header={
    "Accept":"application/json", 
    "x-api-key":api_key
}


b=requests.get("https://api.setlist.fm/rest/1.0/artist/b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d/setlists?p=1", headers=header)
print(b)

b_df=pd.DataFrame(b.json())
b_df.head()
# Out:
# <Response [200]>
#        type  itemsPerPage  page  total  \
# 0  setlists            20     1   1466
# 1  setlists            20     1   1466
# 2  setlists            20     1   1466
# 3  setlists            20     1   1466
# 4  setlists            20     1   1466
#
#                                              setlist
# 0  {'id': '53d6f3ad', 'versionId': 'g53c29b9d', '...
# 1  {'id': '73c18a19', 'versionId': '13367d11', 'e...
# 2  {'id': '43c26b8b', 'versionId': 'g2bc1485a', '...
# 3  {'id': 'bf88dc2', 'versionId': '1b3bcd80', 'ev...
# 4  {'id': '73d67e09', 'versionId': '7b069680', 'e...

# %%
b_setlist_df = b_df['setlist'].apply(pd.Series)
b_setlist_df.head()
# Out:
#          id  versionId   eventDate                   lastUpdated  \
# 0  53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# 1  73c18a19   13367d11  04-09-1968  2020-01-17T01:22:37.000+0000
# 2  43c26b8b  g2bc1485a  25-06-1967  2022-02-24T08:01:13.000+0000
# 3   bf88dc2   1b3bcd80  24-06-1967  2020-06-02T08:45:06.000+0000
# 4  73d67e09   7b069680  29-08-1966  2019-07-10T19:44:01.000+0000
#
#                                               artist  \
# 0  {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d...
# 1  {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d...
# 2  {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d...
# 3  {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d...
# 4  {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d...
#
#                                                venue  \
# 0  {'id': '4bd627fe', 'name': 'Apple Corps Roofto...
# 1  {'id': '4bd5973e', 'name': 'Twickenham Studios...
# 2  {'id': '43d207b3', 'name': 'EMI Recording Stud...
# 3  {'id': '43d207b3', 'name': 'EMI Recording Stud...
# 4  {'id': '3bd624d4', 'name': 'Candlestick Park',...
#
#                                                 sets  \
# 0  {'set': [{'song': [{'name': 'Get Back'}, {'nam...
# 1  {'set': [{'name': '"Hey Jude" film sessions', ...
# 2  {'set': [{'song': [{'name': 'All You Need Is L...
# 3  {'set': [{'song': [{'name': 'All You Need Is L...
# 4  {'set': [{'song': [{'name': 'Rock and Roll Mus...
#
#                                                 info  \
# 0  The Beatles' last public performance. Band pla...
# 1                    Broadcast on September 8th 1968
# 2  Representing the UK on 'Our World’ the first l...
# 3                 Open-door rehearsal for the press.
# 4                 Last public performance until 1969
#
#                                                  url  \
# 0  https://www.setlist.fm/setlist/the-beatles/196...
# 1  https://www.setlist.fm/setlist/the-beatles/196...
# 2  https://www.setlist.fm/setlist/the-beatles/196...
# 3  https://www.setlist.fm/setlist/the-beatles/196...
# 4  https://www.setlist.fm/setlist/the-beatles/196...
#
#                                    tour
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4  {'name': 'North American Tour 1966'}

# %%
b_sets_df = b_setlist_df['sets'].apply(pd.Series)
b_sets_df.head()
# Out:
#                                                  set
# 0  [{'song': [{'name': 'Get Back'}, {'name': 'Get...
# 1  [{'name': '"Hey Jude" film sessions', 'song': ...
# 2     [{'song': [{'name': 'All You Need Is Love'}]}]
# 3  [{'song': [{'name': 'All You Need Is Love', 'i...
# 4  [{'song': [{'name': 'Rock and Roll Music', 'co...

# %%
# Out:
#          id  versionId   eventDate                   lastUpdated  \
# 0  53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
#
#                                               artist  \
# 0  {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d...
#
#                                                venue  \
# 0  {'id': '4bd627fe', 'name': 'Apple Corps Roofto...
#
#                                                 sets  \
# 0  {'set': [{'song': [{'name': 'Get Back'}, {'nam...
#
#                                                 info  \
# 0  The Beatles' last public performance. Band pla...
#
#                                                  url tour
# 0  https://www.setlist.fm/setlist/the-beatles/196...  NaN

# %%
b_set_df = b_sets_df['set'].apply(pd.Series)
b_set_df.head()
# Out:
#                                                    0  \
# 0  {'song': [{'name': 'Get Back'}, {'name': 'Get ...
# 1  {'name': '"Hey Jude" film sessions', 'song': [...
# 2       {'song': [{'name': 'All You Need Is Love'}]}
# 3  {'song': [{'name': 'All You Need Is Love', 'in...
# 4  {'song': [{'name': 'Rock and Roll Music', 'cov...
#
#                                                    1
# 0                                                NaN
# 1  {'name': '"Revolution" film sessions', 'song':...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
b_0_df = b_set_df[0].apply(pd.Series)
b_0_df.head()

# this is now a list of dictionaries
# look up pd.dataframe and different ways to do it
# look into .transpose
#
# Out:
#                                                 song                      name
# 0  [{'name': 'Get Back'}, {'name': 'Get Back'}, {...                       NaN
# 1  [{'name': 'It's the David Frost Theme', 'cover...  "Hey Jude" film sessions
# 2                 [{'name': 'All You Need Is Love'}]                       NaN
# 3  [{'name': 'All You Need Is Love', 'info': 'Liv...                       NaN
# 4  [{'name': 'Rock and Roll Music', 'cover': {'mb...                       NaN

# %%
b_song_df = b_0_df['song'].apply(pd.Series)
b_song_df.head()
# Out:
#                                                   0   \
# 0                               {'name': 'Get Back'}
# 1  {'name': 'It's the David Frost Theme', 'cover'...
# 2                   {'name': 'All You Need Is Love'}
# 3  {'name': 'All You Need Is Love', 'info': 'Live...
# 4  {'name': 'Rock and Roll Music', 'cover': {'mbi...
#
#                                                   1   \
# 0                               {'name': 'Get Back'}
# 1  {'name': 'It's Now or Never', 'cover': {'mbid'...
# 2                                                NaN
# 3                                                NaN
# 4                          {'name': 'She's a Woman'}
#
#                                          2   \
# 0             {'name': 'Don't Let Me Down'}
# 1  {'name': 'Hey Jude', 'info': 'Take one'}
# 2                                       NaN
# 3                                       NaN
# 4           {'name': 'If I Needed Someone'}
#
#                                                   3   \
# 0                     {'name': 'I've Got a Feeling'}
# 1  {'name': 'It's the David Frost Theme', 'cover'...
# 2                                                NaN
# 3                                                NaN
# 4                            {'name': 'Day Tripper'}
#
#                                                   4   \
# 0  {'name': 'One After 909', 'info': 'with "Danny...
# 1           {'name': 'Hey Jude', 'info': 'Take two'}
# 2                                                NaN
# 3                                                NaN
# 4                        {'name': 'Baby's in Black'}
#
#                                                   5   \
# 0  {'name': 'Dig a Pony', 'info': 'with a false s...
# 1  {'name': 'It's the David Frost Theme', 'cover'...
# 2                                                NaN
# 3                                                NaN
# 4                            {'name': 'I Feel Fine'}
#
#                                                   6   \
# 0  {'name': 'God Save the Queen', 'cover': {'mbid...
# 1  {'name': 'You Are My Sunshine', 'cover': {'mbi...
# 2                                                NaN
# 3                                                NaN
# 4                              {'name': 'Yesterday'}
#
#                                                   7   \
# 0  {'name': 'I've Got a Feeling', 'info': 'with "...
# 1         {'name': 'Hey Jude', 'info': 'Take three'}
# 2                                                NaN
# 3                                                NaN
# 4                    {'name': 'I Wanna Be Your Man'}
#
#                               8   \
# 0  {'name': 'Don't Let Me Down'}
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4        {'name': 'Nowhere Man'}
#
#                                                   9   \
# 0  {'name': 'Get Back', 'info': 'Cut short by pol...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                       {'name': 'Paperback Writer'}
#
#                                                   10
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'name': 'Long Tall Sally', 'cover': {'mbid': ...

# %%
b_dict =b_song_df[1]
b_dict_2 =b_dict[0]
print(b_dict_2)
# Out:
# {'name': 'Get Back'}

# %%
b_song_df[[1,2]]
# Out:
#                                                     1  \
# 0                                {'name': 'Get Back'}
# 1   {'name': 'It's Now or Never', 'cover': {'mbid'...
# 2                                                 NaN
# 3                                                 NaN
# 4                           {'name': 'She's a Woman'}
# 5                           {'name': 'She's a Woman'}
# 6                           {'name': 'She's a Woman'}
# 7                           {'name': 'She's a Woman'}
# 8                           {'name': 'She's a Woman'}
# 9                           {'name': 'She's a Woman'}
# 10                          {'name': 'She's a Woman'}
# 11                          {'name': 'She's a Woman'}
# 12                          {'name': 'She's a Woman'}
# 13                          {'name': 'She's a Woman'}
# 14                          {'name': 'She's a Woman'}
# 15                          {'name': 'She's a Woman'}
# 16                          {'name': 'She's a Woman'}
# 17                          {'name': 'She's a Woman'}
# 18                          {'name': 'She's a Woman'}
# 19                          {'name': 'She's a Woman'}
#
#                                            2
# 0              {'name': 'Don't Let Me Down'}
# 1   {'name': 'Hey Jude', 'info': 'Take one'}
# 2                                        NaN
# 3                                        NaN
# 4            {'name': 'If I Needed Someone'}
# 5            {'name': 'If I Needed Someone'}
# 6            {'name': 'If I Needed Someone'}
# 7            {'name': 'If I Needed Someone'}
# 8            {'name': 'If I Needed Someone'}
# 9            {'name': 'If I Needed Someone'}
# 10           {'name': 'If I Needed Someone'}
# 11           {'name': 'If I Needed Someone'}
# 12           {'name': 'If I Needed Someone'}
# 13           {'name': 'If I Needed Someone'}
# 14           {'name': 'If I Needed Someone'}
# 15           {'name': 'If I Needed Someone'}
# 16           {'name': 'If I Needed Someone'}
# 17           {'name': 'If I Needed Someone'}
# 18           {'name': 'If I Needed Someone'}
# 19           {'name': 'If I Needed Someone'}

# %%
print(b_dict_2['name'])
# Out:
# Get Back

# %%
b_dict_2.keys()
# Out:
# dict_keys(['name'])

# %%
print('Items --> ', b_dict_2.items())
# Out:
# Items -->  dict_items([('name', 'Get Back')])

# %% [markdown]
# # c
#
# ## /1.0/city/{geoId}
#
# - couldn't find geoID

# %% [markdown]
# # d
#
# ## /1.0/search/artists

# %%
header={
    "Accept":"application/json", 
    "x-api-key":api_key
}


d=requests.get("https://api.setlist.fm/rest/1.0/search/artists?artistName=The%20Beatles&p=1&sort=sortName", headers=header)
d_df=pd.DataFrame(d.json())
d_df.head()
# Out:
#       type  itemsPerPage  page  total  \
# 0  artists            30     1     47
# 1  artists            30     1     47
# 2  artists            30     1     47
# 3  artists            30     1     47
# 4  artists            30     1     47
#
#                                               artist
# 0  {'mbid': '9725f5a1-3d65-488a-8a82-54c1483beb7c...
# 1  {'mbid': 'ec996b5f-89c8-4dd6-8063-1bd8df438a00...
# 2  {'mbid': '898e211b-06ad-460b-85ee-cd6ac337ef79...
# 3  {'mbid': '31f6812d-12ab-406f-a13d-ad54976e49c6...
# 4  {'mbid': 'f94d056f-68dc-4a99-b664-fa296a96240f...

# %%
d_artist_df = d_df['artist'].apply(pd.Series)
d_artist_df.head()
# Out:
#                                    mbid                    name  \
# 0  9725f5a1-3d65-488a-8a82-54c1483beb7c        The Anal Beatles
# 1  ec996b5f-89c8-4dd6-8063-1bd8df438a00    The Backbeat Beatles
# 2  898e211b-06ad-460b-85ee-cd6ac337ef79  The Beatles Connection
# 3  31f6812d-12ab-406f-a13d-ad54976e49c6      The Cavern Beatles
# 4  f94d056f-68dc-4a99-b664-fa296a96240f  The Beatles First Five
#
#                   sortName        disambiguation  \
# 0        Anal Beatles, The
# 1    Backbeat Beatles, The
# 2  Beatles Connection, The  Beatles Tribute Band
# 3       Beatles Cover Band    Beatles Cover Band
# 4  Beatles First Five, The
#
#                                                  url
# 0  https://www.setlist.fm/setlists/the-anal-beatl...
# 1  https://www.setlist.fm/setlists/the-backbeat-b...
# 2  https://www.setlist.fm/setlists/the-beatles-co...
# 3  https://www.setlist.fm/setlists/the-cavern-bea...
# 4  https://www.setlist.fm/setlists/the-beatles-fi...

# %% [markdown]
# # e
#
# ## /1.0/search/cities

# %%
header={
    "Accept":"application/json", 
    "x-api-key":api_key
}


e=requests.get("https://api.setlist.fm/rest/1.0/search/cities?p=1&stateCode=TN", headers=header)
e_df=pd.DataFrame(e.json())
e_df.head()
# Out:
#      type  itemsPerPage  page  total  \
# 0  cities            50     1    228
# 1  cities            50     1    228
# 2  cities            50     1    228
# 3  cities            50     1    228
# 4  cities            50     1    228
#
#                                               cities
# 0  {'id': '4619405', 'name': 'Ducktown', 'state':...
# 1  {'id': '4615179', 'name': 'Cookville Dock', 's...
# 2  {'id': '4661964', 'name': 'Tazewell', 'state':...
# 3  {'id': '4663081', 'name': 'Townsend', 'state':...
# 4  {'id': '4632745', 'name': 'Jacksonville', 'sta...

# %%
e_cities_df = e_df['cities'].apply(pd.Series)
e_cities_df.head()
# Out:
#         id            name      state stateCode  \
# 0  4619405        Ducktown  Tennessee        TN
# 1  4615179  Cookville Dock  Tennessee        TN
# 2  4661964        Tazewell  Tennessee        TN
# 3  4663081        Townsend  Tennessee        TN
# 4  4632745    Jacksonville  Tennessee        TN
#
#                                      coords  \
# 0  {'lat': 35.0359126, 'long': -84.3827013}
# 1   {'lat': 36.001174, 'long': -85.6516478}
# 2     {'lat': 36.45425, 'long': -83.569352}
# 3  {'lat': 35.6753657, 'long': -83.7557282}
# 4      {'lat': 36.30007, 'long': -89.31952}
#
#                                    country
# 0  {'code': 'US', 'name': 'United States'}
# 1  {'code': 'US', 'name': 'United States'}
# 2  {'code': 'US', 'name': 'United States'}
# 3  {'code': 'US', 'name': 'United States'}
# 4  {'code': 'US', 'name': 'United States'}

# %% [markdown]
# # f
#
# ## /1.0/search/countries

# %%
header={
    "Accept":"application/json", 
    "x-api-key":api_key
}


f=requests.get("https://api.setlist.fm/rest/1.0/search/countries", headers=header)
f_df=pd.DataFrame(f.json())
f_df.head()
# Out:
#         type  itemsPerPage  page  total  \
# 0  countries           250     1    250
# 1  countries           250     1    250
# 2  countries           250     1    250
# 3  countries           250     1    250
# 4  countries           250     1    250
#
#                                           country
# 0               {'code': 'AD', 'name': 'Andorra'}
# 1  {'code': 'AE', 'name': 'United Arab Emirates'}
# 2           {'code': 'AF', 'name': 'Afghanistan'}
# 3     {'code': 'AG', 'name': 'Antigua & Barbuda'}
# 4              {'code': 'AI', 'name': 'Anguilla'}

# %%
f_country_df = f_df['country'].apply(pd.Series)
f_country_df.head()
# Out:
#   code                  name
# 0   AD               Andorra
# 1   AE  United Arab Emirates
# 2   AF           Afghanistan
# 3   AG     Antigua & Barbuda
# 4   AI              Anguilla

# %% [markdown]
# # g
#
# ## /1.0/search/setlists

# %%
header={
    "Accept":"application/json", 
    "x-api-key":api_key
}


g=requests.get("https://api.setlist.fm/rest/1.0/search/setlists?countryCode=US&p=1", headers=header)
g_df=pd.DataFrame(g.json())
g_df.head()
# Out:
#        type  itemsPerPage  page    total  \
# 0  setlists            20     1  2798724
# 1  setlists            20     1  2798724
# 2  setlists            20     1  2798724
# 3  setlists            20     1  2798724
# 4  setlists            20     1  2798724
#
#                                              setlist
# 0  {'id': 'bbf3976', 'versionId': 'g3be5ecd8', 'e...
# 1  {'id': '1bbf3970', 'versionId': 'g3be5ece4', '...
# 2  {'id': '6bbf3e86', 'versionId': 'g23e5ecff', '...
# 3  {'id': '6bbf3e8e', 'versionId': 'g23e5ec0f', '...
# 4  {'id': '63bf3e8f', 'versionId': 'g33e5ec1d', '...

# %%
g_setlist_df = g_df['setlist'].apply(pd.Series)
g_setlist_df.head()
# Out:
#          id  versionId   eventDate                   lastUpdated  \
# 0   bbf3976  g3be5ecd8  28-11-2022  2022-11-26T00:47:09.000+0000
# 1  1bbf3970  g3be5ece4  28-11-2022  2022-11-26T00:45:54.000+0000
# 2  6bbf3e86  g23e5ecff  28-11-2022  2022-11-26T00:41:17.000+0000
# 3  6bbf3e8e  g23e5ec0f  28-11-2022  2022-11-26T00:38:47.000+0000
# 4  63bf3e8f  g33e5ec1d  28-11-2022  2022-11-26T00:35:42.000+0000
#
#                                               artist  \
# 0  {'mbid': '434feab0-1e1e-417d-9822-7fc3a45019f0...
# 1  {'mbid': '7561ff6c-2ab7-4776-9a9a-662f23b2effc...
# 2  {'mbid': 'deeea939-7f89-4762-b09f-79269cd70d3b...
# 3  {'mbid': '9c9921b0-6f5e-44c4-a705-902c630ce754...
# 4  {'mbid': '5b6ebfe0-f72b-4902-bba9-74c8af0f1af0...
#
#                                                venue         sets  \
# 0  {'id': 'bd4d51a', 'name': 'Empire Garage', 'ci...  {'set': []}
# 1  {'id': 'bd4d51a', 'name': 'Empire Garage', 'ci...  {'set': []}
# 2  {'id': '7bd20268', 'name': 'Bert Ogden Arena',...  {'set': []}
# 3  {'id': '2bd02c76', 'name': 'Kia Forum', 'city'...  {'set': []}
# 4  {'id': '2bd02c76', 'name': 'Kia Forum', 'city'...  {'set': []}
#
#                                                  url  \
# 0  https://www.setlist.fm/setlist/black-anvil/202...
# 1  https://www.setlist.fm/setlist/dark-funeral/20...
# 2  https://www.setlist.fm/setlist/queensryche/202...
# 3  https://www.setlist.fm/setlist/blackstarkids/2...
# 4  https://www.setlist.fm/setlist/the-1975/2022/k...
#
#                                    tour                          info
# 0                                   NaN                           NaN
# 1                                   NaN                           NaN
# 2  {'name': 'North American Tour 2022'}  Opening act for Judas Priest
# 3                                   NaN      Opening act for The 1975
# 4        {'name': 'At Their Very Best'}                           NaN

# %%
g_venue_df = g_setlist_df['venue'].apply(pd.Series)
g_venue_df.head()
# Out:
#          id              name  \
# 0   bd4d51a     Empire Garage
# 1   bd4d51a     Empire Garage
# 2  7bd20268  Bert Ogden Arena
# 3  2bd02c76         Kia Forum
# 4  2bd02c76         Kia Forum
#
#                                                 city  \
# 0  {'id': '4671654', 'name': 'Austin', 'state': '...
# 1  {'id': '4671654', 'name': 'Austin', 'state': '...
# 2  {'id': '4688275', 'name': 'Edinburg', 'state':...
# 3  {'id': '5359488', 'name': 'Inglewood', 'state'...
# 4  {'id': '5359488', 'name': 'Inglewood', 'state'...
#
#                                                  url
# 0  https://www.setlist.fm/venue/empire-garage-aus...
# 1  https://www.setlist.fm/venue/empire-garage-aus...
# 2  https://www.setlist.fm/venue/bert-ogden-arena-...
# 3  https://www.setlist.fm/venue/kia-forum-inglewo...
# 4  https://www.setlist.fm/venue/kia-forum-inglewo...

# %%
g_city_df =g_venue_df['city'].apply(pd.Series)
g_city_df.head()
# Out:
#         id       name       state stateCode  \
# 0  4671654     Austin       Texas        TX
# 1  4671654     Austin       Texas        TX
# 2  4688275   Edinburg       Texas        TX
# 3  5359488  Inglewood  California        CA
# 4  5359488  Inglewood  California        CA
#
#                                       coords  \
# 0    {'lat': 30.267153, 'long': -97.7430608}
# 1    {'lat': 30.267153, 'long': -97.7430608}
# 2   {'lat': 26.3017374, 'long': -98.1633433}
# 3  {'lat': 33.9616801, 'long': -118.3531311}
# 4  {'lat': 33.9616801, 'long': -118.3531311}
#
#                                    country
# 0  {'code': 'US', 'name': 'United States'}
# 1  {'code': 'US', 'name': 'United States'}
# 2  {'code': 'US', 'name': 'United States'}
# 3  {'code': 'US', 'name': 'United States'}
# 4  {'code': 'US', 'name': 'United States'}

# %%
g_artist_df = g_setlist_df['artist'].apply(pd.Series)
g_artist_df.head()
# Out:
#                                    mbid           name       sortName  \
# 0  434feab0-1e1e-417d-9822-7fc3a45019f0    Black Anvil    Black Anvil
# 1  7561ff6c-2ab7-4776-9a9a-662f23b2effc   Dark Funeral   Dark Funeral
# 2  deeea939-7f89-4762-b09f-79269cd70d3b    Queensrÿche    Queensrÿche
# 3  9c9921b0-6f5e-44c4-a705-902c630ce754  BLACKSTARKIDS  BLACKSTARKIDS
# 4  5b6ebfe0-f72b-4902-bba9-74c8af0f1af0       The 1975      1975, The
#
#   disambiguation                                                url
# 0                 https://www.setlist.fm/setlists/black-anvil-5b...
# 1                 https://www.setlist.fm/setlists/dark-funeral-4...
# 2                 https://www.setlist.fm/setlists/queensryche-3d...
# 3                 https://www.setlist.fm/setlists/blackstarkids-...
# 4                 https://www.setlist.fm/setlists/the-1975-6bdf8...

# %% [markdown]
# # h
#
# ## /1.0/search/venues

# %%
header={
    "Accept":"application/json", 
    "x-api-key":api_key
}


h=requests.get("https://api.setlist.fm/rest/1.0/search/venues?p=1&stateCode=TN", headers=header)
h_df=pd.DataFrame(h.json())
h_df.head()
# Out:
#      type  itemsPerPage  page  total  \
# 0  venues            30     1   2097
# 1  venues            30     1   2097
# 2  venues            30     1   2097
# 3  venues            30     1   2097
# 4  venues            30     1   2097
#
#                                                venue
# 0  {'id': '63d0623b', 'name': 'lowercase books', ...
# 1  {'id': '4bd5afee', 'name': 'inman Street Coffe...
# 2  {'id': '63d20e47', 'name': 'hatWRKS', 'city': ...
# 3  {'id': '6bd5de4a', 'name': 'aVenue', 'city': {...
# 4  {'id': '2bd0cc0a', 'name': 'Zot', 'city': {'id...

# %%
h_venue_df = h_df['venue'].apply(pd.Series)
h_venue_df.head()
# Out:
#          id                      name  \
# 0  63d0623b           lowercase books
# 1  4bd5afee  inman Street Coffeehouse
# 2  63d20e47                   hatWRKS
# 3  6bd5de4a                    aVenue
# 4  2bd0cc0a                       Zot
#
#                                                 city  \
# 0  {'id': '4634946', 'name': 'Knoxville', 'state'...
# 1  {'id': '4614088', 'name': 'Cleveland', 'state'...
# 2  {'id': '4644585', 'name': 'Nashville', 'state'...
# 3  {'id': '4644585', 'name': 'Nashville', 'state'...
# 4  {'id': '4641239', 'name': 'Memphis', 'state': ...
#
#                                                  url
# 0  https://www.setlist.fm/venue/lowercase-books-k...
# 1  https://www.setlist.fm/venue/inman-street-coff...
# 2  https://www.setlist.fm/venue/hatwrks-nashville...
# 3  https://www.setlist.fm/venue/avenue-nashville-...
# 4  https://www.setlist.fm/venue/zot-memphis-tn-us...

# %%
h_city_df = h_venue_df['city'].apply(pd.Series)
h_city_df.head()
# Out:
#         id       name      state stateCode  \
# 0  4634946  Knoxville  Tennessee        TN
# 1  4614088  Cleveland  Tennessee        TN
# 2  4644585  Nashville  Tennessee        TN
# 3  4644585  Nashville  Tennessee        TN
# 4  4641239    Memphis  Tennessee        TN
#
#                                      coords  \
# 0  {'lat': 35.9606384, 'long': -83.9207392}
# 1  {'lat': 35.1595182, 'long': -84.8766115}
# 2  {'lat': 36.1658899, 'long': -86.7844432}
# 3  {'lat': 36.1658899, 'long': -86.7844432}
# 4  {'lat': 35.1495343, 'long': -90.0489801}
#
#                                    country
# 0  {'code': 'US', 'name': 'United States'}
# 1  {'code': 'US', 'name': 'United States'}
# 2  {'code': 'US', 'name': 'United States'}
# 3  {'code': 'US', 'name': 'United States'}
# 4  {'code': 'US', 'name': 'United States'}

# %%
h_coords_df = h_city_df['coords'].apply(pd.Series)
h_coords_df.head()
# Out:
#          lat       long
# 0  35.960638 -83.920739
# 1  35.159518 -84.876611
# 2  36.165890 -86.784443
# 3  36.165890 -86.784443
# 4  35.149534 -90.048980

# %% [markdown]
# # i
#
# ## /1.0/setlist/{setlistId}

# %%
header={
    "Accept":"application/json", 
    "x-api-key":api_key
}


i=requests.get("https://api.setlist.fm/rest/1.0/setlist/53d6f3ad", headers=header)
i_df=pd.DataFrame(i.json())
i_df
# Out:
#                       id  versionId   eventDate                   lastUpdated  \
# mbid            53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# name            53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# sortName        53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# disambiguation  53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# url             53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# id              53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# city            53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# set             53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
#
#                                                            artist  \
# mbid                         b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d
# name                                                  The Beatles
# sortName                                             Beatles, The
# disambiguation
# url             https://www.setlist.fm/setlists/the-beatles-23...
# id                                                            NaN
# city                                                          NaN
# set                                                           NaN
#
#                                                             venue  \
# mbid                                                          NaN
# name                                          Apple Corps Rooftop
# sortName                                                      NaN
# disambiguation                                                NaN
# url             https://www.setlist.fm/venue/apple-corps-rooft...
# id                                                       4bd627fe
# city            {'id': '2643743', 'name': 'London', 'state': '...
# set                                                           NaN
#
#                                                              sets  \
# mbid                                                          NaN
# name                                                          NaN
# sortName                                                      NaN
# disambiguation                                                NaN
# url                                                           NaN
# id                                                            NaN
# city                                                          NaN
# set             [{'song': [{'name': 'Get Back'}, {'name': 'Get...
#
#                                                              info  \
# mbid            The Beatles' last public performance. Band pla...
# name            The Beatles' last public performance. Band pla...
# sortName        The Beatles' last public performance. Band pla...
# disambiguation  The Beatles' last public performance. Band pla...
# url             The Beatles' last public performance. Band pla...
# id              The Beatles' last public performance. Band pla...
# city            The Beatles' last public performance. Band pla...
# set             The Beatles' last public performance. Band pla...
#
#                                                               url
# mbid            https://www.setlist.fm/setlist/the-beatles/196...
# name            https://www.setlist.fm/setlist/the-beatles/196...
# sortName        https://www.setlist.fm/setlist/the-beatles/196...
# disambiguation  https://www.setlist.fm/setlist/the-beatles/196...
# url             https://www.setlist.fm/setlist/the-beatles/196...
# id              https://www.setlist.fm/setlist/the-beatles/196...
# city            https://www.setlist.fm/setlist/the-beatles/196...
# set             https://www.setlist.fm/setlist/the-beatles/196...

# %% [markdown]
# # j
#
# ## /1.0/setlist/version/{versionId}

# %%
header={
    "Accept":"application/json", 
    "x-api-key":api_key
}


j=requests.get("https://api.setlist.fm/rest/1.0/setlist/version/g53c29b9d", headers=header)
j_df=pd.DataFrame(j.json())
j_df
# Out:
#                       id  versionId   eventDate                   lastUpdated  \
# mbid            53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# name            53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# sortName        53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# disambiguation  53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# url             53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# id              53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# city            53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
# set             53d6f3ad  g53c29b9d  30-01-1969  2021-12-14T08:26:08.000+0000
#
#                                                            artist  \
# mbid                         b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d
# name                                                  The Beatles
# sortName                                             Beatles, The
# disambiguation
# url             https://www.setlist.fm/setlists/the-beatles-23...
# id                                                            NaN
# city                                                          NaN
# set                                                           NaN
#
#                                                             venue  \
# mbid                                                          NaN
# name                                          Apple Corps Rooftop
# sortName                                                      NaN
# disambiguation                                                NaN
# url             https://www.setlist.fm/venue/apple-corps-rooft...
# id                                                       4bd627fe
# city            {'id': '2643743', 'name': 'London', 'state': '...
# set                                                           NaN
#
#                                                              sets  \
# mbid                                                          NaN
# name                                                          NaN
# sortName                                                      NaN
# disambiguation                                                NaN
# url                                                           NaN
# id                                                            NaN
# city                                                          NaN
# set             [{'song': [{'name': 'Get Back'}, {'name': 'Get...
#
#                                                              info  \
# mbid            The Beatles' last public performance. Band pla...
# name            The Beatles' last public performance. Band pla...
# sortName        The Beatles' last public performance. Band pla...
# disambiguation  The Beatles' last public performance. Band pla...
# url             The Beatles' last public performance. Band pla...
# id              The Beatles' last public performance. Band pla...
# city            The Beatles' last public performance. Band pla...
# set             The Beatles' last public performance. Band pla...
#
#                                                               url
# mbid            https://www.setlist.fm/setlist/the-beatles/196...
# name            https://www.setlist.fm/setlist/the-beatles/196...
# sortName        https://www.setlist.fm/setlist/the-beatles/196...
# disambiguation  https://www.setlist.fm/setlist/the-beatles/196...
# url             https://www.setlist.fm/setlist/the-beatles/196...
# id              https://www.setlist.fm/setlist/the-beatles/196...
# city            https://www.setlist.fm/setlist/the-beatles/196...
# set             https://www.setlist.fm/setlist/the-beatles/196...
